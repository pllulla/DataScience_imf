# %% [markdown]
# # GESTIÓN DE ARCHIVOS
#
# ## CSV
#
# ### Lectura de un csv
#
# Para leer un archivo **csv**, lo primero tenermos que importar la librería que nos permite utilizar las funciones necesarias para su procesamiento, tanto de lectura como de escritura, esta librería es **csv**
#
# Importamos la librería

# %%
import csv

# %% [markdown]
# Salvo que estemos utilizando la librerías como **pandas** que tienen otro tipo de funciones específicas para la lectura de un archivo, con la librería csv, tendremos que utilizar la función <code>open()</code> que recibirá los siguientes parámetros: El nombre del archivo csv y, el modo de apertura del archivo que por lo general, utilizaremos los siguientes:
#
# * **r**: Lectura (*read*), abre un archivo para su lectura, devuelve un error si no existe.
# * **w**: Escritura (*write*), se utiliza cuando vamos a escribir un archivo.
#
# Además también se puede especificar el tipo de archivo que se va a procesar:
#
# * **t**: Texto.
# * **b**: Binario, por ejemplo imágenes.
#
#
# Más información sobre la función **open** https://www.w3schools.com/python/ref_func_open.asp

# %%
compras_file = open('compras.csv', mode='rt')

# %% [markdown]
# Por si misma la asginación a compras_file, no contienen nada, simplemente el objeto de la librería csv, que indica que hemos realizado la apertura del archivo 'compras.csv'

# %%
compras_file
# Out:
# <_io.TextIOWrapper name='compras.csv' mode='rt' encoding='cp1252'>

# %% [markdown]
# Para comenzar a leer el archivo, tenemos que crear el objeto *reader*, para ello utilizamos la funcíon <code>csv.reader</code>

# %%
reader_compras = csv.reader(compras_file)

# %% [markdown]
# De nuevo, aún no tenemos nada, simplemente el objeto lector sobre el csv compras

# %%
reader_compras

# %% [markdown]
# Para ver el contenido interior del mismo, tendríamos o bien recorrer línea a línea el archivo o, utilizar una lista para guardar todo el archivo.

# %%
clean_compras = list(reader_compras)

clean_compras
# Out:
# [['ï»¿FECHA', 'ARTICULO', 'CUANTIA', 'PRECIO UNIDAD', 'TOTAL'],
#  ['15/03/2020', 'Barra Pan', '2', '0.55', '1.1'],
#  ['16/03/2020', 'BolÃ\xadgrafo Bic', '3', '0.22', '0.66'],
#  ['17/03/2020', 'Cuaderno', '1', '1.25', '1.25'],
#  ['18/03/2020', 'Refresco', '5', '0.8', '4'],
#  ['19/03/2020', 'Silla Gamer', '1', '153', '153'],
#  ['20/03/2020', 'Paquete folios A4', '3', '2.48', '7.44'],
#  ['21/03/2020', 'Pack x6 Vaso cristal', '2', '6', '12'],
#  ['22/03/2020', 'Manzanas (Kg.)', '1', '2.48', '2.48'],
#  ['23/03/2020', 'Naranjas (Kg.)', '2', '1.29', '2.58'],
#  ['24/03/2020', 'Naranja Malla', '1', '1.5', '1.5']]

# %%
compras_file = open('compras.csv', mode='rt')

reader_compras = csv.reader(compras_file)

archivo_compras = []

for linea in reader_compras:
    print('Línea del archivo: ', linea)
    archivo_compras.append(linea)
# Out:
# Línea del archivo:  ['ï»¿FECHA', 'ARTICULO', 'CUANTIA', 'PRECIO UNIDAD', 'TOTAL']
# Línea del archivo:  ['15/03/2020', 'Barra Pan', '2', '0.55', '1.1']
# Línea del archivo:  ['16/03/2020', 'BolÃ\xadgrafo Bic', '3', '0.22', '0.66']
# Línea del archivo:  ['17/03/2020', 'Cuaderno', '1', '1.25', '1.25']
# Línea del archivo:  ['18/03/2020', 'Refresco', '5', '0.8', '4']
# Línea del archivo:  ['19/03/2020', 'Silla Gamer', '1', '153', '153']
# Línea del archivo:  ['20/03/2020', 'Paquete folios A4', '3', '2.48', '7.44']
# Línea del archivo:  ['21/03/2020', 'Pack x6 Vaso cristal', '2', '6', '12']
# Línea del archivo:  ['22/03/2020', 'Manzanas (Kg.)', '1', '2.48', '2.48']
# Línea del archivo:  ['23/03/2020', 'Naranjas (Kg.)', '2', '1.29', '2.58']
# Línea del archivo:  ['24/03/2020', 'Naranja Malla', '1', '1.5', '1.5']

# %%
archivo_compras
# Out:
# [['ï»¿FECHA', 'ARTICULO', 'CUANTIA', 'PRECIO UNIDAD', 'TOTAL'],
#  ['15/03/2020', 'Barra Pan', '2', '0.55', '1.1'],
#  ['16/03/2020', 'BolÃ\xadgrafo Bic', '3', '0.22', '0.66'],
#  ['17/03/2020', 'Cuaderno', '1', '1.25', '1.25'],
#  ['18/03/2020', 'Refresco', '5', '0.8', '4'],
#  ['19/03/2020', 'Silla Gamer', '1', '153', '153'],
#  ['20/03/2020', 'Paquete folios A4', '3', '2.48', '7.44'],
#  ['21/03/2020', 'Pack x6 Vaso cristal', '2', '6', '12'],
#  ['22/03/2020', 'Manzanas (Kg.)', '1', '2.48', '2.48'],
#  ['23/03/2020', 'Naranjas (Kg.)', '2', '1.29', '2.58'],
#  ['24/03/2020', 'Naranja Malla', '1', '1.5', '1.5']]

# %% [markdown]
# Como podemos comprobar hay algunos fallos de escritura como 'BolÃ\xadgrafo Bic', para solventar estos problemas tenemos que utilizar una codificación específica del archivo, para esta tarea, utilizamos el parámetro `encoding`, lo más habitual es utilizar la codificación **utf-8**

# %%
# Modificamos la codificación
compras_file = open('compras.csv', 
                    mode='rt', 
                    encoding='utf-8')

reader_compras = csv.reader(compras_file)
clean_compras = list(reader_compras)
clean_compras
# Out:
# [['\ufeffFECHA', 'ARTICULO', 'CUANTIA', 'PRECIO UNIDAD', 'TOTAL'],
#  ['15/03/2020', 'Barra Pan', '2', '0.55', '1.1'],
#  ['16/03/2020', 'Bolígrafo Bic', '3', '0.22', '0.66'],
#  ['17/03/2020', 'Cuaderno', '1', '1.25', '1.25'],
#  ['18/03/2020', 'Refresco', '5', '0.8', '4'],
#  ['19/03/2020', 'Silla Gamer', '1', '153', '153'],
#  ['20/03/2020', 'Paquete folios A4', '3', '2.48', '7.44'],
#  ['21/03/2020', 'Pack x6 Vaso cristal', '2', '6', '12'],
#  ['22/03/2020', 'Manzanas (Kg.)', '1', '2.48', '2.48'],
#  ['23/03/2020', 'Naranjas (Kg.)', '2', '1.29', '2.58'],
#  ['24/03/2020', 'Naranja Malla', '1', '1.5', '1.5']]

# %%
clean_compras[0][0] = "FECHA"
# clean_compras[0][0].replace("\ufeff", "")

# %%
clean_compras
# Out:
# [['FECHA', 'ARTICULO', 'CUANTIA', 'PRECIO UNIDAD', 'TOTAL'],
#  ['15/03/2020', 'Barra Pan', '2', '0.55', '1.1'],
#  ['16/03/2020', 'Bolígrafo Bic', '3', '0.22', '0.66'],
#  ['17/03/2020', 'Cuaderno', '1', '1.25', '1.25'],
#  ['18/03/2020', 'Refresco', '5', '0.8', '4'],
#  ['19/03/2020', 'Silla Gamer', '1', '153', '153'],
#  ['20/03/2020', 'Paquete folios A4', '3', '2.48', '7.44'],
#  ['21/03/2020', 'Pack x6 Vaso cristal', '2', '6', '12'],
#  ['22/03/2020', 'Manzanas (Kg.)', '1', '2.48', '2.48'],
#  ['23/03/2020', 'Naranjas (Kg.)', '2', '1.29', '2.58'],
#  ['24/03/2020', 'Naranja Malla', '1', '1.5', '1.5']]

# %%
import csv

# Modificamos la codificación
compras_file = open('C:/Users/JM/Desktop/6_PRESENCIAL_DATA_SCIENCE_6_EDICION/compras.csv', 
                    mode='rt', 
                    encoding='utf-8')

reader_compras = csv.reader(compras_file)
clean_compras = list(reader_compras)
clean_compras
# Out:
# [['\ufeffFECHA', 'ARTICULO', 'CUANTIA', 'PRECIO UNIDAD', 'TOTAL'],
#  ['15/03/2020', 'Barra Pan', '2', '0.55', '1.1'],
#  ['16/03/2020', 'Bolígrafo Bic', '3', '0.22', '0.66'],
#  ['17/03/2020', 'Cuaderno', '1', '1.25', '1.25'],
#  ['18/03/2020', 'Refresco', '5', '0.8', '4'],
#  ['19/03/2020', 'Silla Gamer', '1', '153', '153'],
#  ['20/03/2020', 'Paquete folios A4', '3', '2.48', '7.44'],
#  ['21/03/2020', 'Pack x6 Vaso cristal', '2', '6', '12'],
#  ['22/03/2020', 'Manzanas (Kg.)', '1', '2.48', '2.48'],
#  ['23/03/2020', 'Naranjas (Kg.)', '2', '1.29', '2.58'],
#  ['24/03/2020', 'Naranja Malla', '1', '1.5', '1.5']]

# %%
import csv

# Modificamos la codificación
compras_file = open('C:/Users/JM/Desktop/\
6_PRESENCIAL_DATA_SCIENCE_6_EDICION/compras.csv', 
                    mode='rt', 
                    encoding='utf-8')

reader_compras = csv.reader(compras_file)
clean_compras = list(reader_compras)
clean_compras

# %%
import csv

# Modificamos la codificación

# Da fallo
compras_file = open(r"C:\Users\JM\Desktop\6_PRESENCIAL_DATA_SCIENCE_6_EDICION\\
compras.csv", 
                    mode='rt', 
                    encoding='utf-8')

reader_compras = csv.reader(compras_file)
clean_compras = list(reader_compras)
clean_compras
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 4
#       1 import csv
#       3 # Modificamos la codificación
# ----> 4 compras_file = open(r"C:\Users\JM\Desktop\6_PRESENCIAL_\
#       5 DATA_SCIENCE_6_EDICION\compras.csv",
#       6                     mode='rt',
#       7                     encoding='utf-8')
#       9 reader_compras = csv.reader(compras_file)
#      10 clean_compras = list(reader_compras)
#
# File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# ...

# %%
import csv

path = r"C:\Users\JM\Desktop\6_PRESENCIAL_DATA_SCIENCE_6_EDICION\compras.csv"

# Modificamos la codificación
compras_file = open(path, 
                    mode='rt', 
                    encoding='utf-8')

reader_compras = csv.reader(compras_file)
clean_compras = list(reader_compras)
clean_compras
# Out:
# [['\ufeffFECHA', 'ARTICULO', 'CUANTIA', 'PRECIO UNIDAD', 'TOTAL'],
#  ['15/03/2020', 'Barra Pan', '2', '0.55', '1.1'],
#  ['16/03/2020', 'Bolígrafo Bic', '3', '0.22', '0.66'],
#  ['17/03/2020', 'Cuaderno', '1', '1.25', '1.25'],
#  ['18/03/2020', 'Refresco', '5', '0.8', '4'],
#  ['19/03/2020', 'Silla Gamer', '1', '153', '153'],
#  ['20/03/2020', 'Paquete folios A4', '3', '2.48', '7.44'],
#  ['21/03/2020', 'Pack x6 Vaso cristal', '2', '6', '12'],
#  ['22/03/2020', 'Manzanas (Kg.)', '1', '2.48', '2.48'],
#  ['23/03/2020', 'Naranjas (Kg.)', '2', '1.29', '2.58'],
#  ['24/03/2020', 'Naranja Malla', '1', '1.5', '1.5']]

# %%
"\t"
"\n"
"\\"
# Out:
# '\\'

# %% [markdown]
# ### Escritura de un csv

# %% [markdown]
# Agreagaremos unas cuántas líneas más al .csv, todo compras del mismo día

# %%
type(clean_compras)
# Out:
# list

# %%
clean_compras.append(['24/03/2020', 'Nueva compra 1', '1', '1', '1'])
clean_compras.append(['24/03/2020', 'Nueva compra 2', '2', '1.25', '2.5'])
clean_compras.append(['24/03/2020', 'Nueva compra 3', '1', '2', '2'])

# %%
clean_compras
# Out:
# [['\ufeffFECHA', 'ARTICULO', 'CUANTIA', 'PRECIO UNIDAD', 'TOTAL'],
#  ['15/03/2020', 'Barra Pan', '2', '0.55', '1.1'],
#  ['16/03/2020', 'Bolígrafo Bic', '3', '0.22', '0.66'],
#  ['17/03/2020', 'Cuaderno', '1', '1.25', '1.25'],
#  ['18/03/2020', 'Refresco', '5', '0.8', '4'],
#  ['19/03/2020', 'Silla Gamer', '1', '153', '153'],
#  ['20/03/2020', 'Paquete folios A4', '3', '2.48', '7.44'],
#  ['21/03/2020', 'Pack x6 Vaso cristal', '2', '6', '12'],
#  ['22/03/2020', 'Manzanas (Kg.)', '1', '2.48', '2.48'],
#  ['23/03/2020', 'Naranjas (Kg.)', '2', '1.29', '2.58'],
#  ['24/03/2020', 'Naranja Malla', '1', '1.5', '1.5'],
#  ['24/03/2020', 'Nueva compra 1', '1', '1', '1'],
#  ['24/03/2020', 'Nueva compra 2', '2', '1.25', '2.5'],
#  ['24/03/2020', 'Nueva compra 3', '1', '2', '2']]

# %% [markdown]
# Del mismo modo a como hemos abierto el archivo con `csv.reader`, escribiremos el archivo con `csv.writer`
#
# Para guardar un archivo necesitamos en resumen:
# 1. Establecer cadena de conexión con `open` (modo write text - **wt**)
# 2. Utilizar la función `csv.writer`
# 3. Con nuestro objeto writer utilizar wirte rows `writer.writerows(lista_de_listas)`
# 4. Cerrar la conexión con el archivo con `.close()`

# %%
clean_compras[0][0] = "FECHA"

# %%
file = open('compras_actualizadas.csv', 'wt', newline='')
writer = csv.writer(file)
writer.writerows(clean_compras)
file.close()

# %%
file = open('C:/Users/JM/Downloads/compras_dos.csv', 'wt', newline='')
writer = csv.writer(file)
writer.writerows(clean_compras)
file.close()

# %%
# %ls
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El n£mero de serie del volumen es: 5C2F-7F99
#
#  Directorio de C:\Users\JM\Desktop\6_PRESENCIAL_DATA_SCIENCE_6_EDICION\4_20_04_Python_4
#
# 26/04/2023  20:29    <DIR>          .
# 26/04/2023  20:29    <DIR>          ..
# 26/04/2023  18:58    <DIR>          .ipynb_checkpoints
# 26/04/2023  18:53            19.722 1_5_Funciones_CLASE.ipynb
# 21/11/2022  16:16           909.339 1_5_Fundamentos_Python_4.pdf
# 21/11/2022  16:15         4.976.483 1_5_Fundamentos_Python_4.pptx
# 17/04/2023  11:57         1.434.790 1_5_Fundamentos_Python_4.zip
# 26/04/2023  20:29            39.707 1_6_Gestion_archivos.ipynb
# 29/04/2021  12:14             8.041 1_7_Ejercicios_Estructuras_datos.ipynb
# 29/04/2021  12:14             7.510 1_8_1_Ejercicios_B sicos.ipynb
# 29/04/2021  12:14             5.718 1_8_2_Ejercicio_diccionario_datos.ipynb
# 29/04/2021  12:15            16.636 1_9_1_Python_Ejercicios_Complementarios_1.ipynb
# ...

# %% [markdown]
# Es importante que al terminar de procesar el archivo, lo creemos con la función `close()`

# %% [markdown]
# ### Pregunta
#
# ¿Qué ocurre si ponemos otros valores o directamente quitamos el parámetro `newline` de la función open ?
#
# NOTA: Crea más archivos y comprueba la diferencia.

# %%
file = open('C:/Users/JM/Downloads/compras_tres.csv', 'wt')
writer = csv.writer(file)
writer.writerows(clean_compras)
file.close()

# %% [markdown]
# ## JSON
#
# ### Lectura de un archivo json
#
# importamos la librería json

# %%
import json

# %% [markdown]
# Utilizaremos el mismo procedimiento que con los archivos csv, se utiliza la función `open`, para los archivos json, vamos a distinguir dos funciones principales para poder procesarlos, una es `json.load` y `json.loads`
#
# La principal diferencia entre ambas funciones es que `json.load`se encarga de procesar un archivo json que esté correctamente formateado como tal y tenga una estructura definida. Por su parte, `json.loads` se utiliza para cargar un json como un string, es decir, que no ha sido correctamente formateado, cuando estemos utilizando `json.loads` vamos a procesar el archivo **línea a línea**

# %%
# file = open('mercados.json', 'r')
# mercados = json.load(file)

with open('mercados.json', 'r') as f:
    mercados = json.load(f)

# %%
mercados
# Out:
# {'IBEX_35': [{'ACCIONA': [95.95, 14.7, 95.95, 95.95, 6.302]},
#   {'B. SANTANDER': [2.2195, 9.99, 2.2195, 2.2195, 203.685]},
#   {'IBERDROLA': [8.588, 4.32, 8.588, 8.588, 98.298]}],
#  'IBEX_MEDIUM_CAP': [{'EUSKALTEL': [6.15, 3.71, 6.15, 6.02, 947]},
#   {'LIBERBANK': [0.1552, 7.48, 0.1648, 0.1551, 304.384]},
#   {'SACYR': [1.196, 4.09, 1.226, 1.196, 125.271]}]}

# %%
mercados["IBEX_35"][1]["B. SANTANDER"]
# Out:
# [2.2195, 9.99, 2.2195, 2.2195, 203.685]

# %% [markdown]
# Una vez que cargamos el archivo con `json.load` vemos que es exactamente igual que un diccionario de datos y, podemos emplear las funciones que ya conocemos como keys o values

# %%
mercados.keys()
# Out:
# dict_keys(['IBEX_35', 'IBEX_MEDIUM_CAP'])

# %%
mercados['IBEX_MEDIUM_CAP']
# Out:
# [{'EUSKALTEL': [6.15, 3.71, 6.15, 6.02, 947]},
#  {'LIBERBANK': [0.1552, 7.48, 0.1648, 0.1551, 304.384]},
#  {'SACYR': [1.196, 4.09, 1.226, 1.196, 125.271]}]

# %%
for company in mercados['IBEX_MEDIUM_CAP']:
    print(company)
# Out:
# {'EUSKALTEL': [6.15, 3.71, 6.15, 6.02, 947]}
# {'LIBERBANK': [0.1552, 7.48, 0.1648, 0.1551, 304.384]}
# {'SACYR': [1.196, 4.09, 1.226, 1.196, 125.271]}

# %%
for company in mercados['IBEX_MEDIUM_CAP']:
    for value in company.keys():
        print(company[value])
# Out:
# [6.15, 3.71, 6.15, 6.02, 947]
# [0.1552, 7.48, 0.1648, 0.1551, 304.384]
# [1.196, 4.09, 1.226, 1.196, 125.271]

# %% [markdown]
# Cuando el json no tiene formato... `json.loads`

# %%
with open('tweets.txt', 'r') as f:
    tweets = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[45], line 2
#       1 with open('tweets.txt', 'r') as f:
# ----> 2     tweets = json.load(f)
#
# File ~\anaconda3\lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
# ...

# %% [markdown]
# Al no tener formato, da error, ya que se trta de una composición de varios json el archivo.

# %%
with open('tweets.txt', 'r') as f:
    tweets = json.loads(f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 2
#       1 with open('tweets.txt', 'r') as f:
# ----> 2     tweets = json.loads(f)
#
# File ~\anaconda3\lib\json\__init__.py:339, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337 else:
#     338     if not isinstance(s, (bytes, bytearray)):
# --> 339         raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                         f'not {s.__class__.__name__}')
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
#
# TypeError: the JSON object must be str, bytes or bytearray, not TextIOWrapper

# %% [markdown]
# Tampoco podemos procesar el archivo directamente con la función `json.loads` ya que nos especifica que debe recibir una única cadena de texto, el archivo, son varias cadenas de texto.
#
# Por lo tanto, tenemos que procesar el archivo **línea a línea**

# %%
with open('tweets.txt', 'r') as f:
    for line in f:
        print(line)
# Out:
# {"delete":{"status":{"id":294512601600258048,"id_str":"294512601600258048","user_id":90681582,"user_id_str":"90681582"},"timestamp_ms":"1410368494083"}}
#
# ...

# %%
with open('tweets.txt', 'r') as f:
    for line in f:
        print(type(line))  # TypeError: the JSON object must be str
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
with open('tweets.txt', 'r') as f:
    for line in f:
        print(json.loads(line))
# Out:
# {'delete': {'status': {'id': 294512601600258048, 'id_str': '294512601600258048', 'user_id': 90681582, 'user_id_str': '90681582'}, 'timestamp_ms': '1410368494083'}}
# ...

# %%
with open('tweets.txt', 'r') as f:
    for line in f:
        print(type(json.loads(line))  )
# Out:
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>

# %%
with open('tweets.txt', 'r') as f:
    for line in f:
        print(json.loads(line).keys())
# Out:
# dict_keys(['delete'])
# dict_keys(['created_at', 'id', 'id_str', 'text', 'source', 'truncated', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweet_count', 'favorite_count', 'entities', 'favorited', 'retweeted', 'possibly_sensitive', 'filter_level', 'lang', 'timestamp_ms'])
# dict_keys(['delete'])
# dict_keys(['delete'])
# dict_keys(['delete'])
# dict_keys(['delete'])
# dict_keys(['delete'])
# dict_keys(['delete'])
# dict_keys(['delete'])
# dict_keys(['delete'])
# dict_keys(['delete'])
# dict_keys(['delete'])
# dict_keys(['delete'])
# dict_keys(['delete'])
# ...

# %% [markdown]
# **Podemos guardar todos en una lista de diccionarios**

# %%
# Guardamos el json en una lista
lista_tweets = []

with open('tweets.txt', 'r') as f:
    # Recorremos línea a línea 
    for linea in f:
        tweets = json.loads(linea)
        lista_tweets.append(tweets)

# %%
lista_tweets
# Out:
# [{'delete': {'status': {'id': 294512601600258048,
#     'id_str': '294512601600258048',
#     'user_id': 90681582,
#     'user_id_str': '90681582'},
#    'timestamp_ms': '1410368494083'}},
#  {'created_at': 'Wed Sep 10 17:01:33 +0000 2014',
#   'id': 509748524897292288,
#   'id_str': '509748524897292288',
#   'text': '@Brenamae_ I WHALE SLAP YOUR FIN AND TELL YOU ONE LAST TIME: GO AWHALE',
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'truncated': False,
#   'in_reply_to_status_id': 509748106015948800,
#   'in_reply_to_status_id_str': '509748106015948800',
#   'in_reply_to_user_id': 242563886,
#   'in_reply_to_user_id_str': '242563886',
#   'in_reply_to_screen_name': 'Brenamae_',
#   'user': {'id': 175160659,
#    'id_str': '175160659',
#    'name': 'Butterfly',
#    'screen_name': 'VanessaLilyWan',
#    'location': 'Canada, Montreal',
#    'url': 'http://instagram.com/vanessalilywan',
# ...

# %%
lista_tweets[0]
# Out:
# {'delete': {'status': {'id': 294512601600258048,
#    'id_str': '294512601600258048',
#    'user_id': 90681582,
#    'user_id_str': '90681582'},
#   'timestamp_ms': '1410368494083'}}

# %%
lista_tweets[0].keys()
# Out:
# dict_keys(['delete'])

# %%
lista_tweets[1].keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'source', 'truncated', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweet_count', 'favorite_count', 'entities', 'favorited', 'retweeted', 'possibly_sensitive', 'filter_level', 'lang', 'timestamp_ms'])

# %%
lista_tweets[1]['text']
# Out:
# '@brenamae_ i whale slap your fin and tell you one last time: go awhale'

# %%
lista_tweets[15]
# Out:
# {'created_at': 'Wed Sep 10 17:01:34 +0000 2014',
#  'id': 509748529095774208,
#  'id_str': '509748529095774208',
#  'text': 'RT @byunghns: 😭 I LOVE #틴탑 SO MUCH #쉽지않아 IS GOING TO BE SO GOOD 😭',
#  'source': '<a href="https://twitter.com/download/android" rel="nofollow">Twitter for  Android</a>',
#  'truncated': False,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 2605260731,
#   'id_str': '2605260731',
#   'name': 'gigipluf',
#   'screen_name': 'gigiplu',
#   'location': 'Chile',
#   'url': None,
#   'description': None,
#   'protected': False,
#   'verified': False,
#   'followers_count': 3,
#   'friends_count': 1,
#   'listed_count': 0,
#   'favourites_count': 0,
#   'statuses_count': 656,
#   'created_at': 'Fri Jun 13 02:52:39 +0000 2014',
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'lang': 'es',
# ...

# %% [markdown]
# `JSONDecodeError: Extra data: line 2 column 1 (char 153)` Este error significa que, nuestro archivo json tiene más de un documento por línea, por lo tanto, no se puede cargar directamente con `json.load`, la mejor opción es cargar con `json.loads()`, es decir, cargando cada línea como si fuera una cadena de texto y, formatearlo a diccionario de datos.
#
# Si nada de lo anterior funciona (es decir, que estamos cargando un `TextIOWrapper`), recorrer el archivo línea a línea (con un bucle) y, cargar en cada línea `json.loads()`

# %%
import json

with open("tweets.txt", "rt") as file:
    # raw_tweets = json.load(file)
    # JSONDecodeError: Extra data: line 2 column 1 (char 153)
    
    # raw_tweets = json.loads(file)
    # TypeError: the JSON object must be str, bytes or bytearray, not TextIOWrapper
    
#     for line in file:
#         print(line)
#         print("\t",type(line))

#     for linea in file:
#         print(type(json.loads(line)))

    all_tweets = []
    
    for line in file:
        all_tweets.append(json.loads(line))

# %%
#########################
### Con WITH
#########################
with open("tweets.txt", "rt") as f:
    
    all_tweets = []
    
    for line in f:
        all_tweets.append(json.loads(line))
        
#########################
### SIN WITH
#########################        

f = open("tweets.txt", "rt")

all_tweets = []

for line in f:
    all_tweets.append(json.loads(line))

# %% [markdown]
# ### Escritura de un json
#
# Agregamos nuevos campos.

# %%
mercados
# Out:
# {'IBEX_35': [{'ACCIONA': [95.95, 14.7, 95.95, 95.95, 6.302]},
#   {'B. SANTANDER': [2.2195, 9.99, 2.2195, 2.2195, 203.685]},
#   {'IBERDROLA': [8.588, 4.32, 8.588, 8.588, 98.298]}],
#  'IBEX_MEDIUM_CAP': [{'EUSKALTEL': [6.15, 3.71, 6.15, 6.02, 947]},
#   {'LIBERBANK': [0.1552, 7.48, 0.1648, 0.1551, 304.384]},
#   {'SACYR': [1.196, 4.09, 1.226, 1.196, 125.271]}]}

# %%
new_market = [
    {'New_Market_1': [1, 2, 3, 4, 5]},
    {'New_Market_2': [5, 4, 3, 2, 1]}
]

# %%
mercados.update({'NEW_MARKET' : new_market})

# %%
mercados
# Out:
# {'IBEX_35': [{'ACCIONA': [95.95, 14.7, 95.95, 95.95, 6.302]},
#   {'B. SANTANDER': [2.2195, 9.99, 2.2195, 2.2195, 203.685]},
#   {'IBERDROLA': [8.588, 4.32, 8.588, 8.588, 98.298]}],
#  'IBEX_MEDIUM_CAP': [{'EUSKALTEL': [6.15, 3.71, 6.15, 6.02, 947]},
#   {'LIBERBANK': [0.1552, 7.48, 0.1648, 0.1551, 304.384]},
#   {'SACYR': [1.196, 4.09, 1.226, 1.196, 125.271]}],
#  'NEW_MARKET': [{'New_Market_1': [1, 2, 3, 4, 5]},
#   {'New_Market_2': [5, 4, 3, 2, 1]}]}

# %% [markdown]
# `json.dump(variable con el diccionario, textIoWrapper)`
#
# `json.dump(mercados, outfile)`

# %%
with open('Mercados_update.json', 'w') as outfile:
    json.dump(mercados, outfile)

# %% [markdown]
# Podemos probar a dar un mejor aspecto al json mediante el parámetro `indent`. Más información sobre este parámetro: https://pynative.com/python-prettyprint-json-data/#:~:text=pynative.com%22%20%7D-,After%20writing%20Pretty%2DPrinted%20JSON%20data%20into%20a%20file,indent%3D4%20and%20sorting%20keys.&text=Remember%3A,uses%20four%20spaces%20for%20indentation.

# %%
with open('Mercados_update_ok.json', 'w') as outfile:
    json.dump(mercados, outfile, indent=4)

# %% [markdown]
# ## XML
#
# ### Lectura de un archivo xml
#
# importamos la librería **xml.dom.minidom**

# %%
import xml.dom.minidom

# %% [markdown]
# Lo primero de todo parseamos el archivo xml con la función `parse`, este procedimiento es similar a utilizar la función `open`

# %%
raw_xml = xml.dom.minidom.parse('books.xml')

# %%
raw_xml

# %% [markdown]
# En casi todos los XML tendremos siempre un Elemento principal que abre y cierra el XML, en nuestro caso es Catalog. Para poder procesarlo utilizaremos la función <code>__documentElement__</code>

# %%
libros_object = raw_xml.documentElement

# %%
libros_object

# %% [markdown]
# Como podemos comprobar, ahora nuestro objeto DOM ha encontrado el elemento __Catalog__, por lo que ahora podremos iterar y procesar todos sus elementos o nodos. En este caso, simplemente tenemos elementos Book bajo el elemento general Catalog. Por lo tanto, utilizaremos la función <code>__getElementsByTagName(Nombre_Nodo)__</code>

# %%
books = libros_object.getElementsByTagName('Book')

# %%
books

# %% [markdown]
# Si atendemos a la lista capturada, podremos ver que tenemos dos objetos DOM en los que el elemento es Book, ahora, ya podemos iterar sobre el resto de elementos de cada libro. Si nos fijamos bien, estamos realizando la misma operación de Catalog a Book que de Book a Autor, por lo que de nuevo utilizaremos <code>__getElementsByTagName(Nombre_Nodo)__</code>, en este caso, para ir accediendo a cada campo, de forma iterativa con un bucle for

# %%
for item in books:
    Author = item.getElementsByTagName('Author')
    print(Author)

# %% [markdown]
# Como ya no tenemos más elementos sobre los que iterar, si no que ya queremos acceder directamente al contenido, por ejemplo el primer autor: Garghentini, Davide, tenemos que acceder a los elementos de las listas DOM Element, como podemos comprobar cada lista son de longitud 1, no obstante, lo comprobamos.

# %%
for item in books:
    print(len(item.getElementsByTagName('Author')))
#     Author = item.getElementsByTagName('Author')
#     print(Author)

# %% [markdown]
# Es decir, las listas son indexables por [0], aquí es importante recordar que si tuviéramos más elementos sobre Author, tendríamos que crear un nuevo bucle for para ir recorriendo estos subelementos. Por lo tanto sobre lista del elemento Author, para acceder al contenido utilizamos la función <code>__childNodes__</code> que nos devolverá una nueva lista

# %%
for item in books:
    Author = item.getElementsByTagName('Author')[0].childNodes
    print(Author)

# %% [markdown]
# De nuevo hemos obtenido una lista por cada autor de cada libro, vamos a ver la longitud de estas listas.

# %%
for item in books:
    print(len(item.getElementsByTagName('Author')[0].childNodes))
#     Author = item.getElementsByTagName('Author')[0].childNodes
#     print(Author)

# %% [markdown]
# De nuevo, tenemos solamente un autor, por lo tanto son indexables por [0]

# %%
for item in books:
    Author = item.getElementsByTagName('Author')[0].childNodes[0]
    print(Author)

# %% [markdown]
# Finalmente, vemos que estamos en un nodo conel atributo Text, para poder recuperar este texto, tenemos que hacer uso de la función <code>__.data__</code>

# %%
for item in books:
    Author = item.getElementsByTagName('Author')[0].childNodes[0].data
    print(Author)

# %% [markdown]
# Ya hemos llegado al nombre de cada autor, para comprender este código de una forma más sencilla donde en lugar de obtener un ítem por línea, realicemos nuevos bucles por si la longitud de las lista es diferente podríamos reescribir el anterior código a lo siguiente.

# %%
for item in books:
    target = 'Autor'
    for tag in item.getElementsByTagName('Author'):
        for nodo in tag.childNodes:
            autor = nodo.data
            print(autor)

# %% [markdown]
# Finalmente, podemos mostrar toda la información del XML iterando sobre los nodos hijos del mismo modo que hemos realizado con el autor.

# %%
for item in books:
    print('Procesando libro ...')
    
    # Recuperamos los campos
    Author = item.getElementsByTagName('Author')[0].childNodes[0].data
    Title = item.getElementsByTagName('Title')[0].childNodes[0].data
    Genre = item.getElementsByTagName('Genre')[0].childNodes[0].data
    Price = item.getElementsByTagName('Price')[0].childNodes[0].data
    PublishDate = item.getElementsByTagName('PublishDate')[0].childNodes[0].data
    Description = item.getElementsByTagName('Description')[0].childNodes[0].data
    
    # Imprimimos los campos
    print('\t * Autor: {} '.format(Author))
    print('\t * Título: {} '.format(Title))
    print('\t * Género: {} '.format(Genre))
    print('\t * Precio: {} '.format(Price))
    print('\t * Fecha publicación: {} '.format(PublishDate))
    print('\t * Descripción: {} '.format(Description))
    print('-'*25)

# %% [markdown]
# Análogamente utilizando más bucles para los índices ...

# %%
for item in books:
    print('Procesando libro ...')
    
    target = ['Autor', 'Title', 'Genre', 'Price', 'PublishDate', 'Description']
    
    for elemento in target:
        # Iteramos por cada elemento
        for tag in item.getElementsByTagName(elemento):
            # Iteramos por cada tag name
            for nodo in tag.childNodes:
                # Iteramos por cada nodo
                final_data = nodo.data
                print('\t * {}: {} '.format(elemento, final_data))
    print('-'*25)
