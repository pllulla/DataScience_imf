# %% [markdown]
# # PANDAS
#
# Importamos la librería pandas para poder trabajar con DataFrames en Python, en caso de que no venga instalada por defecto podemos realizar lo siguiente:
# * <code>pip install pandas</code>
# * <code>conda install pandas</code>
# * <code>conda install -c anaconda pandas </code>

# %%
# Importamos pandas, utilizaremos el alias para denominar a cada función de pandas 'pd'
import pandas as pd

# %% [markdown]
# ## Series
#
# Se trata de una colección indexada que funciona de un modo similar a un diccionario de datos, es la unidad mínima con la que podemos trabajar en Pandas, de hecho, un Dataframe no es más que una sucesión de series.
#
# Debemos tener en cuenta que las series funcionan de forma similar a un diccionario de datos donde tenemos los archivos formados por {clave_1: 'valor uno', clave_2. 'valor dos', ....., clave_n: 'valor m'}. Las series pueden formarse a través de un numpy array o una lista y unos valores que actuarán como índices (si no se introducen se tomarán por defecto de 0 a la longitud del conjunto de elementos).
#
# Para crear una serie, simplemente utilizaremos la función <code>**Series**</code>

# %%
b = {
    "Bitcoin": 15613.77,
    "Ethereum" :  496.29,
    
}

# %%
b[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-54af0eb47770> in <module>
# ----> 1 b[0]
#
# KeyError: 0

# %%
criptos = pd.Series(
    [[15613.77, 496.29, 0.52, 0.83, 242.03], 
    ['Bitcoin', 'Ethereum', 'XRP', 'Tether', 'BTC Cash']]
)

criptos
# Out:
# 0        [15613.77, 496.29, 0.52, 0.83, 242.03]
# 1    [Bitcoin, Ethereum, XRP, Tether, BTC Cash]
# dtype: object

# %%
criptos = pd.Series(
    [15613.77, 496.29, 0.52, 0.83, 242.03], 
    index= ['Bitcoin', 'Ethereum', 'XRP', 'Tether', 'BTC Cash']
)

criptos
# Out:
# Bitcoin     15613.77
# Ethereum      496.29
# XRP             0.52
# Tether          0.83
# BTC Cash      242.03
# dtype: float64

# %% [markdown]
# Las seires tienen su propio tipo

# %%
type(criptos) # Clase Series
# Out:
# pandas.core.series.Series

# %%
criptos[0: 2]
# Out:
# Bitcoin     15613.77
# Ethereum      496.29
# dtype: float64

# %%
criptos['Bitcoin']
# Out:
# 15613.77

# %%
b["Bitcoin"]
# Out:
# 15613.77

# %% [markdown]
# ### Pregunta.
#
# Un objeto `pandas.Series` al ser similar a un diccionario de datos, ¿posee funciones similares a un diccionario de datos como `.keys()`o, `.values()`?

# %%
criptos.keys()
# Out:
# Index(['Bitcoin', 'Ethereum', 'XRP', 'Tether', 'BTC Cash'], dtype='object')

# %%
b.keys()
# Out:
# dict_keys(['Bitcoin', 'Ethereum'])

# %%
criptos.values
# Out:
# array([1.561377e+04, 4.962900e+02, 5.200000e-01, 8.300000e-01,
#        2.420300e+02])

# %%
b.values()
# Out:
# dict_values([15613.77, 496.29])

# %% [markdown]
# ## Dataframes
#
# La función principal que nos permite pasar prácticamente cualquier tipo de variable (lista, array, diccionario de datos...) es:
# * <code>__pandas.DataFrame()__</code>
#
# Veremos cómo crear DataFrames desde diferentes estructuras de datos.
#
# * A través de **Series**

# %%
# Creamos un Dataframe a través del objeto Series
df_criptos = pd.DataFrame(criptos)

# Vemos que por defecto, se genera una columna con nombre 0, 
# ya que no se lo hemos especificado.
df_criptos
# Out:
#                  0
# Bitcoin   15613.77
# Ethereum    496.29
# XRP           0.52
# Tether        0.83
# BTC Cash    242.03

# %% [markdown]
# * A través de **Numpy Array**

# %%
# Ejemplo 2 a través numpy array
import numpy as np

# Creamos un array de 5 número aleatorios
array_uno = np.random.rand(5)

pd.DataFrame(array_uno)
# Out:
#           0
# 0  0.136023
# 1  0.367760
# 2  0.047019
# 3  0.684051
# 4  0.872662

# %% [markdown]
# Importante destacar en el ejemplo anterior, que al no utilizar ningún parámetro como índice, automáticamente ha tomado valores de 0 a n

# %% [markdown]
# * A través de **Listas**

# %%
# Ejemplo 3 listas

# Creamos una lista
lista = ['hola mundo', 1, 3.14, 'adios']

# Pasamos la lista a un DataFrame
df_list = pd.DataFrame(lista)

df_list
# Out:
#             0
# 0  hola mundo
# 1           1
# 2        3.14
# 3       adios

# %% [markdown]
# * A través de un **diccionario de datos**

# %%
# Ejemplo 4 Diccionario de datos

# Creamos un Diccionario de datos
dict_cli = {'ID001': 'Cliente uno',
            'ID002': 'Cliente dos',
            'ID003': 'Cliente tres',
            'ID004': 'Cliente cuatro',
            'ID005': 'Cliente cinco'}

dict_cli
# Out:
# {'ID001': 'Cliente uno',
#  'ID002': 'Cliente dos',
#  'ID003': 'Cliente tres',
#  'ID004': 'Cliente cuatro',
#  'ID005': 'Cliente cinco'}

# %%
# Pasamos el dict a un DataFrame

df_dict = pd.DataFrame.from_dict(dict_cli, orient='index')

df_dict
# Out:
#                     0
# ID001     Cliente uno
# ID002     Cliente dos
# ID003    Cliente tres
# ID004  Cliente cuatro
# ID005   Cliente cinco

# %% [markdown]
# Nótese que cuando se trata de un diccionario de datos, tenemos que utilizar el parámetro **orient** para que reconozca correctamente el campo clave como índice. De lo contrario, podemos utilizar el parámetro **index**

# %%
print(type(df_dict))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Ejercicio 1
#
# Tomando la siguiente lista como referencia:

# %%
calificaciones = [
    ('Alberto', 4),
    ('Noelia', 7.25),
    ('Marcos', 9),
    ('Guillermo', 5.25)
]

# %% [markdown]
# Crea un dataframe a través de la lista.
#
# #### Solución

# %%
# En clase

pd.DataFrame(calificaciones)
# Out:
#            0     1
# 0    Alberto  4.00
# 1     Noelia  7.25
# 2     Marcos  9.00
# 3  Guillermo  5.25

# %% [markdown]
# ### Cargando archivos a través de un CSV
#
# Una de las grandes ventajas que supone trabajar con DataFrames es que podemos cargar archivos muy fácilmente y poder procesar sus filas y columnas. Hay varios tipos de datos que podemos cargar a pandas:
#
# * CSV
# * JSON
# * HTML
# * EXCEL
# * HDF5
# * TXT
# * ORC
# * STATA
# * ...
#
# Todos los tipos de datos que podemos cargar se encuentran en el siguiente link: https://pandas.pydata.org/docs/user_guide/io.html#io
#
# A lo largo del contenido mostraremos las principales funcionalidades de los dataframes desde csv como dataframe.
#
# Para cargar un csv como un Dataframe disponemos de la función </code>**read_csv**</code>

# %%
houses = pd.read_csv('housing_California.csv')

# %%
houses
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %% [markdown]
# ### Ejercicio 2
#
# Lee el archivo 'compras_uno.csv' como dataframe
#
# #### Solución

# %%
# En clase

pd.read_csv("compras_uno.csv")
# Out:
#         FECHA              ARTICULO  CUANTIA  PRECIO UNIDAD   TOTAL
# 0  15/03/2020             Barra Pan        2           0.55    1.10
# 1  16/03/2020         Bolígrafo Bic        3           0.22    0.66
# 2  17/03/2020              Cuaderno        1           1.25    1.25
# 3  18/03/2020              Refresco        5           0.80    4.00
# 4  19/03/2020           Silla Gamer        1         153.00  153.00
# 5  20/03/2020     Paquete folios A4        3           2.48    7.44
# 6  21/03/2020  Pack x6 Vaso cristal        2           6.00   12.00
# 7  22/03/2020        Manzanas (Kg.)        1           2.48    2.48
# 8  23/03/2020        Naranjas (Kg.)        2           1.29    2.58
# 9  24/03/2020         Naranja Malla        1           1.50    1.50

# %% [markdown]
# ### Ejercicio 3
#
# Lee el archivo 'compras_dos.csv' como dataframe
#
# #### Solución

# %%
# En clase

pd.read_csv("compras_dos.csv", sep=";")
# Out:
#         FECHA              ARTICULO  CUANTIA  PRECIO UNIDAD   TOTAL
# 0  15/03/2020             Barra Pan        2           0.55    1.10
# 1  16/03/2020         Bolígrafo Bic        3           0.22    0.66
# 2  17/03/2020              Cuaderno        1           1.25    1.25
# 3  18/03/2020              Refresco        5           0.80    4.00
# 4  19/03/2020           Silla Gamer        1         153.00  153.00
# 5  20/03/2020     Paquete folios A4        3           2.48    7.44
# 6  21/03/2020  Pack x6 Vaso cristal        2           6.00   12.00
# 7  22/03/2020        Manzanas (Kg.)        1           2.48    2.48
# 8  23/03/2020        Naranjas (Kg.)        2           1.29    2.58
# 9  24/03/2020         Naranja Malla        1           1.50    1.50

# %% [markdown]
# ### Ejercicio 4
#
# Lee el archivo 'compras_tres.csv' como dataframe
#
# #### Solución

# %%
# En clase

pd.read_csv("compras_tres.csv", sep="\t")
# Out:
#         FECHA              ARTICULO  CUANTIA  PRECIO UNIDAD   TOTAL
# 0  15/03/2020             Barra Pan        2           0.55    1.10
# 1  16/03/2020         Bolígrafo Bic        3           0.22    0.66
# 2  17/03/2020              Cuaderno        1           1.25    1.25
# 3  18/03/2020              Refresco        5           0.80    4.00
# 4  19/03/2020           Silla Gamer        1         153.00  153.00
# 5  20/03/2020     Paquete folios A4        3           2.48    7.44
# 6  21/03/2020  Pack x6 Vaso cristal        2           6.00   12.00
# 7  22/03/2020        Manzanas (Kg.)        1           2.48    2.48
# 8  23/03/2020        Naranjas (Kg.)        2           1.29    2.58
# 9  24/03/2020         Naranja Malla        1           1.50    1.50

# %% [markdown]
# ### Ejercicio 5
#
# Lee de nuevo el archivo 'housing_California.csv' como dataframe, utiliza el parámetro `header=None`
#
# #### Solución

# %%
# En clase

pd.read_csv("housing_California.csv", header=None)
# Out:
#                0         1                   2            3               4  \
# 0      longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 1        -122.23     37.88                41.0        880.0           129.0
# 2        -122.22     37.86                21.0       7099.0          1106.0
# 3        -122.24     37.85                52.0       1467.0           190.0
# 4        -122.25     37.85                52.0       1274.0           235.0
# ...          ...       ...                 ...          ...             ...
# 20636    -121.09     39.48                25.0       1665.0           374.0
# 20637    -121.21     39.49                18.0        697.0           150.0
# 20638    -121.22     39.43                17.0       2254.0           485.0
# 20639    -121.32     39.43                18.0       1860.0           409.0
# 20640    -121.24     39.37                16.0       2785.0           616.0
#
#                 5           6              7                   8  \
# 0      population  households  median_income  median_house_value
# 1           322.0       126.0         8.3252            452600.0
# 2          2401.0      1138.0         8.3014            358500.0
# 3           496.0       177.0         7.2574            352100.0
# 4           558.0       219.0         5.6431            341300.0
# ...           ...         ...            ...                 ...
# 20636       845.0       330.0         1.5603             78100.0
# 20637       356.0       114.0         2.5568             77100.0
# 20638      1007.0       433.0            1.7             92300.0
# 20639       741.0       349.0         1.8672             84700.0
# 20640      1387.0       530.0         2.3886             89400.0
#
#                      9
# 0      ocean_proximity
# 1             NEAR BAY
# 2             NEAR BAY
# 3             NEAR BAY
# 4             NEAR BAY
# ...                ...
# 20636           INLAND
# 20637           INLAND
# 20638           INLAND
# 20639           INLAND
# 20640           INLAND
#
# [20641 rows x 10 columns]

# %%
pd.read_csv("housing_California_copia.csv", header=None)
# Out:
#             0      1     2       3       4       5       6       7         8  \
# 0     -122.23  37.88  41.0   880.0   129.0   322.0   126.0  8.3252  452600.0
# 1     -122.22  37.86  21.0  7099.0  1106.0  2401.0  1138.0  8.3014  358500.0
# 2     -122.24  37.85  52.0  1467.0   190.0   496.0   177.0  7.2574  352100.0
# 3     -122.25  37.85  52.0  1274.0   235.0   558.0   219.0  5.6431  341300.0
# 4     -122.25  37.85  52.0  1627.0   280.0   565.0   259.0  3.8462  342200.0
# ...       ...    ...   ...     ...     ...     ...     ...     ...       ...
# 20635 -121.09  39.48  25.0  1665.0   374.0   845.0   330.0  1.5603   78100.0
# 20636 -121.21  39.49  18.0   697.0   150.0   356.0   114.0  2.5568   77100.0
# 20637 -121.22  39.43  17.0  2254.0   485.0  1007.0   433.0  1.7000   92300.0
# 20638 -121.32  39.43  18.0  1860.0   409.0   741.0   349.0  1.8672   84700.0
# 20639 -121.24  39.37  16.0  2785.0   616.0  1387.0   530.0  2.3886   89400.0
#
#               9
# 0      NEAR BAY
# 1      NEAR BAY
# 2      NEAR BAY
# 3      NEAR BAY
# 4      NEAR BAY
# ...         ...
# 20635    INLAND
# 20636    INLAND
# 20637    INLAND
# 20638    INLAND
# 20639    INLAND
#
# [20640 rows x 10 columns]

# %% [markdown]
# ### Ejercicio 6
#
# Lee de nuevo el archivo 'housing_California.csv' como dataframe, utiliza el parámetro `header=[0,1,2]`
#
# #### Solución

# %%
# En clase

pd.read_csv("housing_California.csv", header=[0,1,2])
# Out:
#       longitude latitude housing_median_age total_rooms total_bedrooms  \
#         -122.23    37.88               41.0       880.0          129.0
#         -122.22    37.86               21.0      7099.0         1106.0
# 0       -122.24    37.85               52.0      1467.0          190.0
# 1       -122.25    37.85               52.0      1274.0          235.0
# 2       -122.25    37.85               52.0      1627.0          280.0
# 3       -122.25    37.85               52.0       919.0          213.0
# 4       -122.25    37.84               52.0      2535.0          489.0
# ...         ...      ...                ...         ...            ...
# 20633   -121.09    39.48               25.0      1665.0          374.0
# 20634   -121.21    39.49               18.0       697.0          150.0
# 20635   -121.22    39.43               17.0      2254.0          485.0
# 20636   -121.32    39.43               18.0      1860.0          409.0
# 20637   -121.24    39.37               16.0      2785.0          616.0
#
#       population households median_income median_house_value ocean_proximity
#            322.0      126.0        8.3252           452600.0        NEAR BAY
#           2401.0     1138.0        8.3014           358500.0        NEAR BAY
# 0          496.0      177.0        7.2574           352100.0        NEAR BAY
# 1          558.0      219.0        5.6431           341300.0        NEAR BAY
# 2          565.0      259.0        3.8462           342200.0        NEAR BAY
# 3          413.0      193.0        4.0368           269700.0        NEAR BAY
# 4         1094.0      514.0        3.6591           299200.0        NEAR BAY
# ...          ...        ...           ...                ...             ...
# 20633      845.0      330.0        1.5603            78100.0          INLAND
# 20634      356.0      114.0        2.5568            77100.0          INLAND
# 20635     1007.0      433.0        1.7000            92300.0          INLAND
# 20636      741.0      349.0        1.8672            84700.0          INLAND
# 20637     1387.0      530.0        2.3886            89400.0          INLAND
#
# [20638 rows x 10 columns]

# %%
pd.read_csv("compras_tres.csv", sep="\t", skiprows=2, header=None)
# Out:
#             0                     1  2       3       4
# 0  16/03/2020         Bolígrafo Bic  3    0.22    0.66
# 1  17/03/2020              Cuaderno  1    1.25    1.25
# 2  18/03/2020              Refresco  5    0.80    4.00
# 3  19/03/2020           Silla Gamer  1  153.00  153.00
# 4  20/03/2020     Paquete folios A4  3    2.48    7.44
# 5  21/03/2020  Pack x6 Vaso cristal  2    6.00   12.00
# 6  22/03/2020        Manzanas (Kg.)  1    2.48    2.48
# 7  23/03/2020        Naranjas (Kg.)  2    1.29    2.58
# 8  24/03/2020         Naranja Malla  1    1.50    1.50

# %% [markdown]
# ### Ejercicio 7
#
#
# Carga el dataset 'housing_California.csv', cargando solamente las columnas housing_median_age y population
#
# #### Solución

# %%
pd.read_csv("housing_California.csv")
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
ej_7 = pd.read_csv('housing_California.csv', usecols = ['housing_median_age', 'population'])

ej_7 # Con usecols podemos definir las columnas que necesitemos cargar en el momento de lectura
# Out:
#        housing_median_age  population
# 0                    41.0       322.0
# 1                    21.0      2401.0
# 2                    52.0       496.0
# 3                    52.0       558.0
# 4                    52.0       565.0
# ...                   ...         ...
# 20635                25.0       845.0
# 20636                18.0       356.0
# 20637                17.0      1007.0
# 20638                18.0       741.0
# 20639                16.0      1387.0
#
# [20640 rows x 2 columns]

# %%
pd.read_csv("housing_California.csv", usecols=[1,2,3])
# Out:
#        latitude  housing_median_age  total_rooms
# 0         37.88                41.0        880.0
# 1         37.86                21.0       7099.0
# 2         37.85                52.0       1467.0
# 3         37.85                52.0       1274.0
# 4         37.85                52.0       1627.0
# ...         ...                 ...          ...
# 20635     39.48                25.0       1665.0
# 20636     39.49                18.0        697.0
# 20637     39.43                17.0       2254.0
# 20638     39.43                18.0       1860.0
# 20639     39.37                16.0       2785.0
#
# [20640 rows x 3 columns]

# %%
pd.read_csv("housing_California.csv", usecols=[3,2,1])
# Out:
#        latitude  housing_median_age  total_rooms
# 0         37.88                41.0        880.0
# 1         37.86                21.0       7099.0
# 2         37.85                52.0       1467.0
# 3         37.85                52.0       1274.0
# 4         37.85                52.0       1627.0
# ...         ...                 ...          ...
# 20635     39.48                25.0       1665.0
# 20636     39.49                18.0        697.0
# 20637     39.43                17.0       2254.0
# 20638     39.43                18.0       1860.0
# 20639     39.37                16.0       2785.0
#
# [20640 rows x 3 columns]

# %% [markdown]
# ### Obtención de Series y Columnas de un dataframe.
#
# Tal y como hemos visto antes un dataframe es una sucesión o colección de series, es decir, que cada columna actúa como una serie ya que todas las columnas comparten el mismo índice.
#
# Para acceder a una columna tenemos que escribir entre corchetes el nombre de la misma.

# %%
criptos
# Out:
# Bitcoin     15613.77
# Ethereum      496.29
# XRP             0.52
# Tether          0.83
# BTC Cash      242.03
# dtype: float64

# %%
houses['housing_median_age']
# Out:
# array([41., 21., 52., ..., 17., 18., 16.])

# %% [markdown]
# Si atendemos al tipo de clase que tiene una columna veremos que es Series

# %%
type(houses['housing_median_age'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Otra forma de acceder a las columnas de un dataframe es:
#
# * nombre_df.__nombre_columna__ (sin las comillas de string)

# %%
houses.housing_median_age
# Out:
# 0        41.0
# 1        21.0
# 2        52.0
# 3        52.0
# 4        52.0
#          ...
# 20635    25.0
# 20636    18.0
# 20637    17.0
# 20638    18.0
# 20639    16.0
# Name: housing_median_age, Length: 20640, dtype: float64

# %% [markdown]
# ### Selección de múltiples columnas
#
# Ahora que ya hemos visto como un DataFrame se compone de Series, podemos ver cómo seleccionar varias columnas. Para ello, simplemente tenemos que encerrar entre corchetes los nombres de las columnas que queremos seleccionar como:
#
# __nombre_df[['columna_uno', 'columna_dos', 'columna_tres']]__
#
# Análogamente, podremos pasar una lista con nombres de las columnas.
#
# Para realizar lo mismo mediante indexación, es decir, obtener un subconjunto de columnas del dataframe por la posición que ocupan las columnas podemos hacer:
# * __nombre_dataframe[nombre_dataframe.columns[[col_n, col_m]]]__
# * __nombre_dataframe.iloc[:, [col_n, col_m]]__
#
# Mediante nombres de columnas.

# %%
houses['housing_median_age']
# Out:
# 0        41.0
# 1        21.0
# 2        52.0
# 3        52.0
# 4        52.0
#          ...
# 20635    25.0
# 20636    18.0
# 20637    17.0
# 20638    18.0
# 20639    16.0
# Name: housing_median_age, Length: 20640, dtype: float64

# %%
houses[['housing_median_age', 'total_bedrooms']]
# Out:
#        housing_median_age  total_bedrooms
# 0                    41.0           129.0
# 1                    21.0          1106.0
# 2                    52.0           190.0
# 3                    52.0           235.0
# 4                    52.0           280.0
# ...                   ...             ...
# 20635                25.0           374.0
# 20636                18.0           150.0
# 20637                17.0           485.0
# 20638                18.0           409.0
# 20639                16.0           616.0
#
# [20640 rows x 2 columns]

# %%
target = ['housing_median_age', 'total_bedrooms', 'population']

houses[target]

# houses[['housing_median_age', 'total_bedrooms', 'population']]
# Out:
#        housing_median_age  total_bedrooms  population
# 0                    41.0           129.0       322.0
# 1                    21.0          1106.0      2401.0
# 2                    52.0           190.0       496.0
# 3                    52.0           235.0       558.0
# 4                    52.0           280.0       565.0
# ...                   ...             ...         ...
# 20635                25.0           374.0       845.0
# 20636                18.0           150.0       356.0
# 20637                17.0           485.0      1007.0
# 20638                18.0           409.0       741.0
# 20639                16.0           616.0      1387.0
#
# [20640 rows x 3 columns]

# %%
target = ["total_bedrooms", 
          'housing_median_age', 
          'population']

houses[target]
# Out:
#        total_bedrooms  housing_median_age  population
# 0               129.0                41.0       322.0
# 1              1106.0                21.0      2401.0
# 2               190.0                52.0       496.0
# 3               235.0                52.0       558.0
# 4               280.0                52.0       565.0
# ...               ...                 ...         ...
# 20635           374.0                25.0       845.0
# 20636           150.0                18.0       356.0
# 20637           485.0                17.0      1007.0
# 20638           409.0                18.0       741.0
# 20639           616.0                16.0      1387.0
#
# [20640 rows x 3 columns]

# %% [markdown]
# Mediante índices

# %%
houses.columns[0:5]
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms'],
#       dtype='object')

# %%
houses.columns[1]
# Out:
# 'latitude'

# %%
houses.columns[0: 4]
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms'], dtype='object')

# %%
houses[['longitude', 'latitude', 'housing_median_age', 'total_rooms']]
# Out:
#        longitude  latitude  housing_median_age  total_rooms
# 0        -122.23     37.88                41.0        880.0
# 1        -122.22     37.86                21.0       7099.0
# 2        -122.24     37.85                52.0       1467.0
# 3        -122.25     37.85                52.0       1274.0
# 4        -122.25     37.85                52.0       1627.0
# ...          ...       ...                 ...          ...
# 20635    -121.09     39.48                25.0       1665.0
# 20636    -121.21     39.49                18.0        697.0
# 20637    -121.22     39.43                17.0       2254.0
# 20638    -121.32     39.43                18.0       1860.0
# 20639    -121.24     39.37                16.0       2785.0
#
# [20640 rows x 4 columns]

# %%
houses[houses.columns[2:6]]
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population
# 0                    41.0        880.0           129.0       322.0
# 1                    21.0       7099.0          1106.0      2401.0
# 2                    52.0       1467.0           190.0       496.0
# 3                    52.0       1274.0           235.0       558.0
# 4                    52.0       1627.0           280.0       565.0
# ...                   ...          ...             ...         ...
# 20635                25.0       1665.0           374.0       845.0
# 20636                18.0        697.0           150.0       356.0
# 20637                17.0       2254.0           485.0      1007.0
# 20638                18.0       1860.0           409.0       741.0
# 20639                16.0       2785.0           616.0      1387.0
#
# [20640 rows x 4 columns]

# %% [markdown]
# Para seleccionar varias columnas con iloc, tenemos que tener en cuenta que un dataframe se distribuye de la siguiente manera.
#
# * __dataframe[filas, columnas]__: En donde tanto filas como columnas son indexables

# %%
houses.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
houses.iloc[ : ,[1,3]]
# Out:
#        latitude  total_rooms
# 0         37.88        880.0
# 1         37.86       7099.0
# 2         37.85       1467.0
# 3         37.85       1274.0
# 4         37.85       1627.0
# ...         ...          ...
# 20635     39.48       1665.0
# 20636     39.49        697.0
# 20637     39.43       2254.0
# 20638     39.43       1860.0
# 20639     39.37       2785.0
#
# [20640 rows x 2 columns]

# %%
# houses.iloc[ : ,['latitude', 'total_rooms']] # Solo funciona con números

# %% [markdown]
# ### Selección de múltiples filas de un dataframe
#
# Por lo general, podemos utilizar las mismas propiedades que las de las listas, salvo seleccionar una única fila que es diferente:
# * Para seleccionar desde la primera fila hasta un límite realizamos: <code>__dataframe[0:n]__</code>, análogamente podemos omitir el cero y realizar simplemente: <code>__dataframe[ :n]__</code>
# * Para seleccionar desde una fila hasta el final realizamos: <code>__dataframe[n:]__</code>
# * Para seleccionar un rango definido de filas realizamos: <code>__dataframe[n:m]__</code>

# %%
# Seleccionamos de la fila 0 a la 2
houses[0:2]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY

# %%
# Vemos que es lo mismo si quitamos el cero.
houses[ :2]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY

# %%
# Seleccionamos de fila n al final
houses[20635:]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND

# %%
# Rango personalizado, escogemos de fila 150 a 200
houses[150:200]
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 150    -122.22     37.81                52.0       2024.0           339.0
# 151    -122.22     37.81                52.0       2944.0           536.0
# 152    -122.23     37.80                52.0       2033.0           486.0
# 153    -122.23     37.81                52.0       1433.0           229.0
# 154    -122.22     37.81                52.0       2927.0           402.0
# 155    -122.23     37.81                52.0       2315.0           292.0
# 156    -122.24     37.81                52.0       2485.0           313.0
# 157    -122.24     37.81                52.0       1490.0           238.0
# 158    -122.23     37.81                52.0       2814.0           365.0
# 159    -122.24     37.81                52.0       2093.0           550.0
# 160    -122.24     37.80                52.0        888.0           168.0
# 161    -122.25     37.80                52.0       2087.0           510.0
# 162    -122.24     37.81                52.0       2513.0           502.0
# 163    -122.25     37.81                46.0       3232.0           835.0
# 164    -122.25     37.80                42.0       4120.0          1065.0
# 165    -122.25     37.80                43.0       2364.0           792.0
# 166    -122.25     37.80                41.0       1471.0           469.0
# 167    -122.25     37.80                29.0       2468.0           864.0
# 168    -122.24     37.79                27.0       1632.0           492.0
# 169    -122.25     37.79                45.0       1786.0           526.0
# 170    -122.25     37.79                50.0        629.0           188.0
# 171    -122.25     37.79                52.0       1339.0           391.0
# 172    -122.25     37.80                36.0       1678.0           606.0
# 173    -122.25     37.80                43.0       2344.0           647.0
# 174    -122.24     37.80                52.0        996.0           228.0
# 175    -122.24     37.80                52.0       1591.0           373.0
# 176    -122.24     37.80                52.0       1586.0           398.0
# 177    -122.24     37.80                47.0       2046.0           588.0
# 178    -122.23     37.80                52.0       1192.0           289.0
# 179    -122.24     37.80                52.0       1803.0           420.0
# 180    -122.24     37.80                49.0       2838.0           749.0
# 181    -122.23     37.80                52.0        783.0           184.0
# 182    -122.23     37.80                51.0       1590.0           414.0
# 183    -122.23     37.80                50.0       1746.0           480.0
# 184    -122.23     37.80                52.0       1252.0           299.0
# 185    -122.23     37.79                43.0       5963.0          1344.0
# 186    -122.23     37.79                52.0       1783.0           395.0
# 187    -122.23     37.79                30.0        999.0           264.0
# 188    -122.24     37.79                39.0       1469.0           431.0
# 189    -122.24     37.79                47.0       1372.0           395.0
# 190    -122.24     37.79                52.0        674.0           180.0
# 191    -122.24     37.79                43.0       1626.0           376.0
# 192    -122.25     37.79                51.0        175.0            43.0
# 193    -122.25     37.79                39.0        461.0           129.0
# 194    -122.25     37.79                52.0        902.0           237.0
# 195    -122.26     37.80                20.0       2373.0           779.0
# 196    -122.22     37.77                52.0        391.0           128.0
# 197    -122.22     37.77                52.0       1137.0           301.0
# 198    -122.23     37.77                52.0        769.0           206.0
# 199    -122.23     37.78                52.0        472.0           146.0
#
#      population  households  median_income  median_house_value ocean_proximity
# 150       756.0       340.0         4.0720            270100.0        NEAR BAY
# 151      1034.0       521.0         5.3509            302100.0        NEAR BAY
# 152       787.0       459.0         3.1603            269500.0        NEAR BAY
# 153       612.0       213.0         4.7708            314700.0        NEAR BAY
# 154      1021.0       380.0         8.1564            390100.0        NEAR BAY
# 155       861.0       258.0         8.8793            410300.0        NEAR BAY
# 156       953.0       327.0         6.8591            352400.0        NEAR BAY
# 157       634.0       256.0         6.0302            287300.0        NEAR BAY
# 158       878.0       352.0         7.5080            348700.0        NEAR BAY
# 159       918.0       483.0         2.7477            243800.0        NEAR BAY
# 160       360.0       175.0         2.1944            211500.0        NEAR BAY
# 161      1197.0       488.0         3.0149            218400.0        NEAR BAY
# 162      1048.0       518.0         3.6750            269900.0        NEAR BAY
# 163      1373.0       747.0         3.2250            218800.0        NEAR BAY
# 164      1715.0      1015.0         2.9345            225000.0        NEAR BAY
# 165      1359.0       722.0         2.1429            250000.0        NEAR BAY
# 166      1062.0       413.0         1.6121            171400.0        NEAR BAY
# 167      1335.0       773.0         1.3929            193800.0        NEAR BAY
# 168      1171.0       429.0         2.3173            125000.0        NEAR BAY
# 169      1475.0       460.0         1.7772             97500.0        NEAR BAY
# 170       742.0       196.0         2.6458            125000.0        NEAR BAY
# 171      1086.0       363.0         2.1810            138800.0        NEAR BAY
# 172      1645.0       543.0         2.2303            116700.0        NEAR BAY
# 173      1710.0       644.0         1.6504            151800.0        NEAR BAY
# 174       731.0       228.0         2.2697            127000.0        NEAR BAY
# 175      1118.0       347.0         2.1563            128600.0        NEAR BAY
# 176      1006.0       335.0         2.1348            140600.0        NEAR BAY
# 177      1213.0       554.0         2.6292            182700.0        NEAR BAY
# 178       772.0       257.0         2.3833            146900.0        NEAR BAY
# 179      1321.0       401.0         2.9570            122800.0        NEAR BAY
# 180      1487.0       677.0         2.5238            169300.0        NEAR BAY
# 181       488.0       186.0         1.9375            126600.0        NEAR BAY
# 182       949.0       392.0         1.9028            127900.0        NEAR BAY
# 183      1149.0       415.0         2.2500            123500.0        NEAR BAY
# 184       844.0       280.0         2.3929            111900.0        NEAR BAY
# 185      4367.0      1231.0         2.1917            112800.0        NEAR BAY
# 186      1659.0       412.0         2.9357            107900.0        NEAR BAY
# 187      1011.0       263.0         1.8854            137500.0        NEAR BAY
# 188      1464.0       389.0         2.1638            105500.0        NEAR BAY
# 189      1237.0       303.0         2.1250             95500.0        NEAR BAY
# 190       647.0       168.0         3.3750            116100.0        NEAR BAY
# 191      1284.0       357.0         2.2542            112200.0        NEAR BAY
# 192       228.0        55.0         2.1000             75000.0        NEAR BAY
# 193       381.0       123.0         1.6000            112500.0        NEAR BAY
# 194       846.0       227.0         3.6250            125000.0        NEAR BAY
# 195      1659.0       676.0         1.6929            115000.0        NEAR BAY
# 196       520.0       138.0         1.6471             95000.0        NEAR BAY
# 197       866.0       259.0         2.5900             96400.0        NEAR BAY
# 198       612.0       183.0         2.5700             72000.0        NEAR BAY
# 199       415.0       126.0         2.6429             71300.0        NEAR BAY

# %% [markdown]
# Para seleccionar una sola fila no podemos hacer la misma operación que en las listas, indexar una única posición <code>lista[n]</code>, ya que esto no nos devuelve nada, para ello, tenemos que seleccionar como un rango personalizado la fila que queremos mostrar más una posición <code>dataframe[n:n+1]</code>

# %%
houses[1000:1000]
# Out:
# Empty DataFrame
# Columns: [longitude, latitude, housing_median_age, total_rooms, total_bedrooms, population, households, median_income, median_house_value, ocean_proximity]
# Index: []

# %%
houses[1000:1001]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1000    -121.76     37.69                29.0       3433.0           711.0
#
#       population  households  median_income  median_house_value  \
# 1000      1919.0       709.0         3.3841            184400.0
#
#      ocean_proximity
# 1000          INLAND

# %% [markdown]
# **Para una sola fila mejor `iloc`**

# %%
houses.iloc[-2]
# Out:
# longitude             -121.32
# latitude                39.43
# housing_median_age       18.0
# total_rooms            1860.0
# total_bedrooms          409.0
# population              741.0
# households              349.0
# median_income          1.8672
# median_house_value    84700.0
# ocean_proximity        INLAND
# Name: 20638, dtype: object

# %%
# houses.iloc[start:end:step , # Filas 
#             start:end:step   #Columnas
#            ]

# %% [markdown]
# ### Resumen función iloc
#
# Con la función __.iloc__ podemos seleccionar varias filas de una forma muy sencilla que puede resumirse como:
# * <code>dataframe.iloc[0]</code> - Primera fila de un dataframe.
# * <code>dataframe.iloc[1]</code> - Segunda fila de un dataframe.
# * <code>dataframe.iloc[-1]</code> - (Indexación negativa) Última fila de un dataframe
# * <code>dataframe.iloc[[n]]</code> - Fila _n_ del dataframe.
# * <code>dataframe.iloc[n:m]</code> - Rango personalizado de las filas _n_ a _m_
#
# En columnas el resumen de la función __.iloc__ pasaría a ser:
# * <code>dataframe.iloc[:, 0]</code> - Primera columna de un dataframe.
# * <code>dataframe.iloc[:, 1]</code> - Segunda columna de un dataframe.
# * <code>dataframe.iloc[:, -1]</code> - (Indexación negativa) Última columna de un dataframe
# * <code>dataframe.iloc[:,[n,m]]</code> - Exactamente, las columnas _n_ y _m_ de un dataframe.
# * <code>dataframe.iloc[:, n:m]</code> - Rango personalizado de las columnas _n_ a _m_ de un dataframe.
#
# Podemos también realizar una selección múltiple de columnas filas con __.iloc__ con los siguientes ejemplos:
# * <code>dataframe.iloc[[0,5,7,9], [1,4]]</code> - Selección de las filas 0,5,7,9 de las columnas 1 y 4
# * <code>dataframe.iloc[0:10, 0:2]</code> - Selección basada en rangos de las filas 0 a 10 de las columnas 0 a 2

# %%
houses.iloc[[20,5680,19875], [3, 5]]
# Out:
#        total_rooms  population
# 20           751.0       409.0
# 5680        1933.0       902.0
# 19875        792.0       641.0

# %%
houses.iloc[0:10, 0:3]
# Out:
#    longitude  latitude  housing_median_age
# 0    -122.23     37.88                41.0
# 1    -122.22     37.86                21.0
# 2    -122.24     37.85                52.0
# 3    -122.25     37.85                52.0
# 4    -122.25     37.85                52.0
# 5    -122.25     37.85                52.0
# 6    -122.25     37.84                52.0
# 7    -122.25     37.84                52.0
# 8    -122.26     37.84                42.0
# 9    -122.25     37.84                52.0

# %% [markdown]
# ### Índices de un DataFrame
#
# Se tratan de las posiciones que ocupa cada fila dentro de un dataframe, a no ser que se especifique un tipo de índice concreto basado en etiquetas, los índices serán de 0 a la longitud total del dataframe

# %%
# Creamos un dataframe
ventas = {
   'region': ["EUROPA", "EUROPA", "EUROPA", 
              "USA", "USA", "USA", "LATAM", "LATAM"],
   'ventas': [153752, 168742, 162587, 256198, 285743, 290371, 145638, 151678],
   'anio'  : [2018, 2019, 2020, 2018, 2019, 2020, 2018, 2019]
}

df = pd.DataFrame(ventas)
df
# Out:
#    region  ventas  anio
# 0  EUROPA  153752  2018
# 1  EUROPA  168742  2019
# 2  EUROPA  162587  2020
# 3     USA  256198  2018
# 4     USA  285743  2019
# 5     USA  290371  2020
# 6   LATAM  145638  2018
# 7   LATAM  151678  2019

# %% [markdown]
# Para observar el índice de un dataframe podemos hacer uso de su atributo <code>**index**</code>

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %% [markdown]
# Dependiendo de cómo estén formados nuestros datos, vamos a poder crear multi índices basados en columnas propias de nuestro dataframe, si nos fijamos la columna region y anio tienen elementos repetidos. Esto nos permitirá hacer multi-índices donde tengamos un continente por año de ventas.
#
# Con la función <code> set_index()</code> vamos a poder establecer un nuevo índice

# %%
region_year = df.set_index(["region", "anio"])
region_year
# Out:
#              ventas
# region anio
# EUROPA 2018  153752
#        2019  168742
#        2020  162587
# USA    2018  256198
#        2019  285743
#        2020  290371
# LATAM  2018  145638
#        2019  151678

# %%
region_year.index
# Out:
# MultiIndex([('EUROPA', 2018),
#             ('EUROPA', 2019),
#             ('EUROPA', 2020),
#             (   'USA', 2018),
#             (   'USA', 2019),
#             (   'USA', 2020),
#             ( 'LATAM', 2018),
#             ( 'LATAM', 2019)],
#            names=['region', 'anio'])

# %% [markdown]
# En vista del nuevo dataframe, podemos ver que ahora las columnas region y anio actúan como índice, por lo que si consultamos la primera fila...

# %%
houses.iloc[0]
# Out:
# longitude              -122.23
# latitude                 37.88
# housing_median_age        41.0
# total_rooms              880.0
# total_bedrooms           129.0
# population               322.0
# households               126.0
# median_income           8.3252
# median_house_value    452600.0
# ocean_proximity       NEAR BAY
# Name: 0, dtype: object

# %%
region_year.iloc[0]
# Out:
# ventas    153752
# Name: (EUROPA, 2018), dtype: int64

# %%
region_year.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_37ab8_row0_col0 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_37ab8_row1_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_37ab8_row2_col0 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_37ab8_row3_col0 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_37ab8_row4_col0 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_37ab8_row5_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_37ab8_row6_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_37ab8_row7_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_37ab8_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ventas</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >region</th>
#       <th class="index_name level1" >anio</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37ab8_level0_row0" class="row_heading level0 row0" rowspan="3">EUROPA</th>
#       <th id="T_37ab8_level1_row0" class="row_heading level1 row0" >2018</th>
#       <td id="T_37ab8_row0_col0" class="data row0 col0" >153752</td>
#     </tr>
#     <tr>
#       <th id="T_37ab8_level1_row1" class="row_heading level1 row1" >2019</th>
#       <td id="T_37ab8_row1_col0" class="data row1 col0" >168742</td>
#     </tr>
#     <tr>
#       <th id="T_37ab8_level1_row2" class="row_heading level1 row2" >2020</th>
#       <td id="T_37ab8_row2_col0" class="data row2 col0" >162587</td>
#     </tr>
#     <tr>
#       <th id="T_37ab8_level0_row3" class="row_heading level0 row3" rowspan="3">USA</th>
#       <th id="T_37ab8_level1_row3" class="row_heading level1 row3" >2018</th>
#       <td id="T_37ab8_row3_col0" class="data row3 col0" >256198</td>
#     </tr>
#     <tr>
#       <th id="T_37ab8_level1_row4" class="row_heading level1 row4" >2019</th>
#       <td id="T_37ab8_row4_col0" class="data row4 col0" >285743</td>
#     </tr>
#     <tr>
#       <th id="T_37ab8_level1_row5" class="row_heading level1 row5" >2020</th>
#       <td id="T_37ab8_row5_col0" class="data row5 col0" >290371</td>
#     </tr>
#     <tr>
#       <th id="T_37ab8_level0_row6" class="row_heading level0 row6" rowspan="2">LATAM</th>
#       <th id="T_37ab8_level1_row6" class="row_heading level1 row6" >2018</th>
#       <td id="T_37ab8_row6_col0" class="data row6 col0" >145638</td>
#     </tr>
#     <tr>
#       <th id="T_37ab8_level1_row7" class="row_heading level1 row7" >2019</th>
#       <td id="T_37ab8_row7_col0" class="data row7 col0" >151678</td>
#     </tr>
#   </tbody>
# </table>

# %%
region_year.loc["EUROPA"]
# Out:
#       ventas
# anio
# 2018  153752
# 2019  168742
# 2020  162587

# %% [markdown]
# Obtenemos el dato que pertenece al volumen de ventas, siendo region (Europe) y el año (2018) sus índices
#
# Del mismo modo, podemos pasar una lista como índice a un dataframe. Obviamente, esta lista debe ser de la misma longitud que el dataframe.

# %%
df
# Out:
#    region  ventas  anio
# 0  EUROPA  153752  2018
# 1  EUROPA  168742  2019
# 2  EUROPA  162587  2020
# 3     USA  256198  2018
# 4     USA  285743  2019
# 5     USA  290371  2020
# 6   LATAM  145638  2018
# 7   LATAM  151678  2019

# %%
indice = ['REGISTRO_1', 'REGISTRO_2', 'REGISTRO_3', 'REGISTRO_4', 
          'REGISTRO_5', 'REGISTRO_6', 'REGISTRO_7', 'REGISTRO_8']

df.index = indice

df
# Out:
#             region  ventas  anio
# REGISTRO_1  EUROPA  153752  2018
# REGISTRO_2  EUROPA  168742  2019
# REGISTRO_3  EUROPA  162587  2020
# REGISTRO_4     USA  256198  2018
# REGISTRO_5     USA  285743  2019
# REGISTRO_6     USA  290371  2020
# REGISTRO_7   LATAM  145638  2018
# REGISTRO_8   LATAM  151678  2019

# %% [markdown]
# Con la función <code>.loc</code> podemos buscar elementos en el índice

# %%
df.loc['REGISTRO_6']
# Out:
# region       USA
# ventas    290371
# anio        2020
# Name: REGISTRO_6, dtype: object

# %% [markdown]
# Al igual que podemos modificar el atributo `index` también podemos modificar `columns`

# %%
df.columns = ["region", "sales", "year"]

# %%
df
# Out:
#             region   sales  year
# REGISTRO_1  EUROPA  153752  2018
# REGISTRO_2  EUROPA  168742  2019
# REGISTRO_3  EUROPA  162587  2020
# REGISTRO_4     USA  256198  2018
# REGISTRO_5     USA  285743  2019
# REGISTRO_6     USA  290371  2020
# REGISTRO_7   LATAM  145638  2018
# REGISTRO_8   LATAM  151678  2019

# %% [markdown]
# ### Ejercicio 8
#
# Crea un nuevo dataframe que contenga la siguiente información.
#
# * Se van a introducir datos de las asignatura de Matemáticas un alumno.
# * Para la asignatura se solicitará al usuario la calificación obtenida
# * Se preguntará al usuario desde que año a que año se va a consultar la información
# * Se tomarán como índice los años de dichas calificaciones
#
# #### Solución

# %%
# Solicitamos los años

año_inicio = int(input('Introduce el primer año para consultar datos --> '))
año_fin = int(input('Introduce el último año para consultar datos --> '))

while not año_fin > año_inicio:
    print('El último año debe ser mayor que el de inicio')
    año_inicio = int(input('Introduce el primer año para consultar datos --> '))
    año_fin = int(input('Introduce el último año para consultar datos --> '))
# Out:
# Introduce el primer año para consultar datos --> 2019
# Introduce el último año para consultar datos --> 2016
# El último año debe ser mayor que el de inicio
# Introduce el primer año para consultar datos --> 2018
# Introduce el último año para consultar datos --> 2023

# %%
print('Años seleccionados desde: {}, hasta: {}'.format(año_inicio, año_fin))
# Out:
# Años seleccionados desde: 2018, hasta: 2023

# %%
# Solicitamos las calificaciones

anios = range(año_inicio, año_fin+1)

# %%
calificaciones_matematicas = []

# Recorremos los años
for anio in anios:
    nota_mates = float(input('Introduce la nota en matemáticas para el año ' + str(anio) + ': ' ))
    calificaciones_matematicas.append(nota_mates)
# Out:
# Introduce la nota en matemáticas para el año 2018: 3.25
# Introduce la nota en matemáticas para el año 2019: 2.20
# Introduce la nota en matemáticas para el año 2020: 5
# Introduce la nota en matemáticas para el año 2021: 6
# Introduce la nota en matemáticas para el año 2022: 8.75
# Introduce la nota en matemáticas para el año 2023: 6.5

# %%
print('Las calificaciones son ', calificaciones_matematicas)
# Out:
# Las calificaciones son  [3.25, 2.2, 5.0, 6.0, 8.75, 6.5]

# %%
# Construimos el dataframe

calificaciones = {
   'anio': anios,
   'calificaciones': calificaciones_matematicas
}

# %%
calificaciones
# Out:
# {'anio': range(2018, 2024), 'calificaciones': [3.25, 2.2, 5.0, 6.0, 8.75, 6.5]}

# %%
calificaciones = pd.DataFrame(calificaciones)

# %%
calificaciones
# Out:
#    anio  calificaciones
# 0  2018            3.25
# 1  2019            2.20
# 2  2020            5.00
# 3  2021            6.00
# 4  2022            8.75
# 5  2023            6.50

# %%
calificaciones.index = calificaciones.anio

# %%
calificaciones.style.background_gradient("coolwarm")
# Out:
# <style type="text/css">
# #T_8bab3_row0_col0, #T_8bab3_row1_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8bab3_row0_col1 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_8bab3_row1_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_8bab3_row2_col0 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_8bab3_row2_col1 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_8bab3_row3_col0 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_8bab3_row3_col1 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_8bab3_row4_col0 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_8bab3_row4_col1, #T_8bab3_row5_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8bab3_row5_col1 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# </style>
# <table id="T_8bab3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >anio</th>
#       <th class="col_heading level0 col1" >calificaciones</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >anio</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8bab3_level0_row0" class="row_heading level0 row0" >2018</th>
#       <td id="T_8bab3_row0_col0" class="data row0 col0" >2018</td>
#       <td id="T_8bab3_row0_col1" class="data row0 col1" >3.250000</td>
#     </tr>
#     <tr>
#       <th id="T_8bab3_level0_row1" class="row_heading level0 row1" >2019</th>
#       <td id="T_8bab3_row1_col0" class="data row1 col0" >2019</td>
#       <td id="T_8bab3_row1_col1" class="data row1 col1" >2.200000</td>
#     </tr>
#     <tr>
#       <th id="T_8bab3_level0_row2" class="row_heading level0 row2" >2020</th>
#       <td id="T_8bab3_row2_col0" class="data row2 col0" >2020</td>
#       <td id="T_8bab3_row2_col1" class="data row2 col1" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8bab3_level0_row3" class="row_heading level0 row3" >2021</th>
#       <td id="T_8bab3_row3_col0" class="data row3 col0" >2021</td>
#       <td id="T_8bab3_row3_col1" class="data row3 col1" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8bab3_level0_row4" class="row_heading level0 row4" >2022</th>
#       <td id="T_8bab3_row4_col0" class="data row4 col0" >2022</td>
#       <td id="T_8bab3_row4_col1" class="data row4 col1" >8.750000</td>
#     </tr>
#     <tr>
#       <th id="T_8bab3_level0_row5" class="row_heading level0 row5" >2023</th>
#       <td id="T_8bab3_row5_col0" class="data row5 col0" >2023</td>
#       <td id="T_8bab3_row5_col1" class="data row5 col1" >6.500000</td>
#     </tr>
#   </tbody>
# </table>

# %%
calificaciones.drop(["anio"], 1, inplace=True)
# Out:
# C:\Users\JMMoreno\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
calificaciones
# Out:
#       calificaciones
# anio
# 2018            3.25
# 2019            2.20
# 2020            5.00
# 2021            6.00
# 2022            8.75
# 2023            6.50

# %% [markdown]
# ### Algunas funciones básicas de un dataframe
#
# A continuación, vamos a ver un listado de algunas de las principales funciones que podemos aplicar en un dataframe para operar en sus columnas:
#
# * Obtener las primeras filas de un dataframe con __<code>.head</code>__
# * Obtener las últimas filas de un dataframe con __<code>.tail</code>__
# * Obtener los elmentos únicos de una columna de un dataframe con __<code>.unique</code>__
# * Obtener la frecuencia de los valores únicos de una columna de un dataframe __<code>.value_counts</code>__
# * Obtener un resumen estadístico del dataset con __<code>.describe</code>__
# * Obtener la media de una columna con __<code>.mean</code>__
# * Obtener una copia de un dataframe con __<code>.copy</code>__
# * Ver los nombres de las columnas de un dataframe con __<code>.columns</code>__
# * Obtener la correlación entre todas las variables numéricas con __<code>.corr</code>__
# * Borrar duplicados de un dataframe con __<code>.drop_duplicates</code>__
# * Especialmente para Big Data sets podemos ver el consumo en memoria RAM de nuestro dataset con __<code>.memory_usage</code>__
# * Ver un resumen resumen gráfico (basado en densidad, scatter plots y gráficas de correlaciones) de todas las variables del dataframe con __<code>.scatter_matrix</code>__
# * Obtener un histograma de cada variable numérica del dataset con __<code>.hist</code>__

# %% [markdown]
# ### Primeras filas de un Dataframe

# %%
# Primeras filas del dataframe
houses.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# Si en .head() no especificamos nada, por defecto, se muestran 5, podemos especificar el número de filas a mostrar.

# %%
houses.head(9)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
# 5       413.0       193.0         4.0368            269700.0        NEAR BAY
# 6      1094.0       514.0         3.6591            299200.0        NEAR BAY
# 7      1157.0       647.0         3.1200            241400.0        NEAR BAY
# 8      1206.0       595.0         2.0804            226700.0        NEAR BAY

# %% [markdown]
# ### Últimas filas de un Dataframe
#
# Lo mismo pasa con el comando __tail__, si no le pasamos como parámetro el número de filas a visualizar, tomará las últimas 5

# %%
houses.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND

# %%
houses.tail(2)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20638          INLAND
# 20639          INLAND

# %% [markdown]
# ### Valores únicos por columna

# %%
# Observamos los valores únicos de la columna 
houses['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
houses['latitude'].unique()
# Out:
# array([37.88, 37.86, 37.85, 37.84, 37.83, 37.82, 37.81, 37.8 , 37.79,
#        37.77, 37.78, 37.76, 37.75, 37.74, 37.73, 37.9 , 37.89, 37.87,
#        37.72, 37.71, 37.7 , 37.69, 37.68, 37.64, 37.63, 37.66, 37.65,
#        37.67, 37.61, 37.62, 37.6 , 37.59, 37.58, 37.57, 37.49, 37.52,
#        37.56, 37.55, 37.54, 37.53, 37.51, 37.48, 37.47, 37.5 , 38.69,
#        38.72, 38.52, 38.48, 38.45, 38.46, 38.43, 38.55, 38.54, 38.51,
#        38.5 , 38.47, 38.44, 38.42, 38.37, 38.34, 38.32, 38.26, 38.38,
#        38.4 , 38.39, 38.36, 38.31, 39.76, 39.78, 39.77, 39.74, 39.75,
#        39.73, 39.71, 39.72, 39.7 , 39.82, 39.79, 39.68, 39.64, 39.66,
#        39.59, 39.88, 40.06, 39.97, 39.86, 39.83, 39.8 , 39.69, 39.61,
#        39.65, 39.55, 39.52, 39.53, 39.6 , 39.54, 39.5 , 39.49, 39.51,
#        39.48, 39.47, 39.45, 39.44, 39.43, 39.4 , 39.39, 39.33, 39.37,
#        39.35, 39.34, 39.32, 39.36, 39.38, 39.42, 39.41, 38.15, 38.12,
#        38.09, 38.07, 37.97, 38.24, 38.2 , 38.16, 38.11, 38.28, 38.19,
#        38.25, 38.41, 38.33, 38.35, 38.21, 38.23, 38.29, 39.03, 38.99,
#        39.  , 39.15, 39.22, 39.25, 39.1 , 39.13, 39.31, 39.3 , 39.21,
#        38.03, 38.04, 38.  , 37.98, 37.99, 37.93, 37.94, 37.95, 37.96,
#        37.91, 38.01, 38.02, 38.05, 37.92, 38.06, 41.8 , 41.75, 41.77,
#        41.78, 41.73, 41.76, 41.74, 41.95, 41.92, 41.84, 41.81, 41.68,
#        41.88, 41.54, 38.96, 38.95, 38.94, 38.93, 38.92, 38.91, 38.89,
#        38.9 , 38.88, 38.87, 38.84, 38.76, 38.86, 39.06, 39.04, 39.01,
#        38.81, 38.83, 38.85, 38.68, 38.67, 38.66, 38.7 , 38.58, 38.73,
#        38.65, 38.62, 38.79, 38.77, 38.71, 38.75, 38.74, 38.6 , 38.61,
#        38.57, 38.53, 38.8 , 38.63, 36.73, 36.74, 36.72, 36.75, 36.71,
#        36.7 , 36.68, 36.69, 36.65, 36.64, 36.62, 36.63, 36.59, 36.77,
#        36.76, 36.8 , 36.79, 36.81, 36.78, 36.66, 36.83, 36.85, 36.82,
#        36.84, 36.86, 36.91, 36.87, 36.94, 36.88, 36.89, 37.1 , 37.02,
#        37.  , 37.25, 37.13, 37.09, 37.12, 37.11, 37.06, 36.61, 36.6 ,
#        36.58, 36.57, 36.56, 36.55, 36.52, 36.51, 36.53, 36.44, 36.46,
#        36.43, 36.54, 36.45, 36.34, 36.16, 36.21, 36.19, 36.29, 36.18,
#        36.14, 36.15, 36.13, 36.49, 36.97, 40.8 , 40.79, 40.78, 40.77,
#        40.75, 40.76, 40.81, 40.86, 40.85, 40.87, 40.88, 40.9 , 40.66,
#        40.91, 41.03, 41.32, 41.09, 41.11, 41.3 , 41.01, 41.36, 41.13,
#        41.06, 41.04, 40.97, 40.92, 40.89, 40.93, 41.02, 40.99, 40.95,
#        40.94, 40.72, 40.73, 40.74, 40.67, 40.69, 40.62, 40.6 , 40.59,
#        40.55, 40.57, 40.48, 40.58, 40.5 , 40.44, 40.47, 40.45, 40.54,
#        40.28, 40.22, 40.24, 40.16, 40.12, 40.11, 40.05, 33.12, 33.13,
#        33.19, 33.24, 33.2 , 33.09, 33.04, 32.99, 32.96, 32.98, 32.97,
#        32.82, 32.76, 32.86, 32.81, 32.85, 32.84, 32.83, 32.87, 32.8 ,
#        32.79, 32.75, 32.77, 32.73, 32.78, 32.69, 32.7 , 32.67, 32.68,
#        33.33, 32.93, 32.74, 33.41, 33.4 , 33.38, 33.32, 33.36, 33.34,
#        33.3 , 33.28, 33.26, 33.43, 33.07, 33.35, 37.35, 37.4 , 37.39,
#        37.37, 37.36, 37.17, 36.95, 36.4 , 36.  , 35.42, 35.45, 35.44,
#        35.43, 35.41, 35.4 , 35.39, 35.38, 35.37, 35.34, 35.36, 35.35,
#        35.32, 35.33, 35.3 , 35.31, 35.27, 35.22, 35.24, 35.28, 34.82,
#        34.83, 34.81, 34.95, 35.06, 35.07, 35.19, 35.17, 35.16, 35.14,
#        35.15, 35.13, 35.5 , 35.52, 35.49, 35.51, 35.6 , 35.55, 35.58,
#        35.59, 35.62, 35.65, 35.76, 35.64, 35.68, 35.67, 35.78, 35.77,
#        35.75, 35.79, 35.74, 35.47, 35.72, 35.7 , 35.48, 35.63, 35.61,
#        35.73, 35.54, 35.05, 35.03, 35.21, 35.12, 35.08, 35.1 , 34.92,
#        34.86, 34.99, 35.  , 34.87, 35.04, 35.2 , 35.26, 35.23, 36.41,
#        36.37, 36.38, 36.32, 36.31, 36.3 , 36.33, 36.27, 36.28, 36.35,
#        36.36, 36.25, 36.11, 36.09, 36.1 , 36.08, 36.2 , 35.99, 36.02,
#        36.04, 36.01, 35.87, 35.91, 39.23, 39.18, 39.17, 39.14, 39.12,
#        39.11, 39.09, 39.08, 39.02, 39.07, 39.05, 38.98, 38.97, 38.82,
#        38.78, 41.07, 41.12, 40.98, 40.63, 40.65, 40.51, 40.35, 40.43,
#        40.42, 40.41, 40.36, 40.37, 40.38, 40.29, 40.31, 40.17, 40.26,
#        39.92, 34.27, 34.26, 34.25, 34.24, 34.22, 34.21, 34.28, 34.29,
#        34.32, 34.33, 34.31, 34.3 , 34.23, 34.2 , 34.19, 34.18, 34.17,
#        34.16, 34.15, 34.14, 34.13, 34.12, 34.11, 34.1 , 34.09, 34.08,
#        34.07, 34.06, 34.05, 34.04, 34.03, 34.02, 34.01, 34.  , 33.99,
#        33.98, 33.97, 33.94, 33.95, 33.96, 33.93, 33.92, 33.91, 33.9 ,
#        33.88, 33.89, 33.87, 33.86, 33.85, 33.84, 33.83, 33.82, 33.81,
#        33.8 , 33.79, 33.78, 33.77, 33.76, 33.75, 33.74, 33.73, 33.72,
#        33.69, 33.71, 33.67, 33.68, 34.71, 34.63, 34.58, 34.74, 34.68,
#        34.69, 34.65, 34.7 , 34.67, 34.72, 34.76, 34.77, 34.66, 34.62,
#        34.73, 34.59, 34.57, 34.53, 34.61, 34.6 , 34.56, 34.64, 34.55,
#        34.51, 34.43, 34.41, 34.52, 34.5 , 34.46, 34.44, 34.49, 34.48,
#        34.45, 34.4 , 34.47, 34.42, 34.39, 34.38, 34.37, 34.36, 37.34,
#        37.32, 37.29, 37.21, 37.38, 37.31, 37.33, 37.23, 37.19, 37.27,
#        37.04, 36.99, 36.93, 36.98, 36.96, 36.9 , 36.92, 38.1 , 38.14,
#        38.13, 38.08, 38.18, 37.43, 37.46, 39.81, 39.67, 39.46, 39.26,
#        39.28, 39.2 , 39.16, 37.44, 37.42, 37.41, 37.2 , 37.26, 37.16,
#        37.3 , 37.28, 37.18, 37.01, 37.08, 37.07, 37.05, 37.03, 41.31,
#        41.35, 41.82, 41.79, 41.4 , 41.61, 36.67, 36.5 , 36.47, 36.48,
#        36.42, 36.24, 35.95, 35.94, 36.06, 38.3 , 38.27, 38.22, 38.17,
#        38.49, 38.56, 38.59, 39.24, 39.19, 39.27, 39.29, 33.61, 33.62,
#        33.6 , 33.63, 33.59, 33.58, 33.57, 33.65, 33.64, 33.54, 33.55,
#        33.56, 33.51, 33.52, 33.66, 33.53, 33.42, 33.47, 33.45, 33.46,
#        33.44, 33.48, 33.49, 33.5 , 33.7 , 39.93, 39.9 , 39.95, 39.96,
#        40.02, 40.08, 40.14, 40.01, 40.13, 40.27, 40.23, 40.19, 40.3 ,
#        40.25, 38.64, 34.54, 34.34, 34.91, 34.9 , 34.89, 34.35, 34.85,
#        34.84, 34.98, 34.75, 34.88, 34.94, 34.96, 32.72, 32.71, 32.66,
#        32.88, 32.92, 32.89, 32.91, 32.9 , 32.94, 32.95, 32.59, 32.58,
#        32.57, 32.56, 32.55, 32.54, 32.63, 32.65, 32.64, 32.62, 32.61,
#        32.6 , 33.01, 33.  , 33.02, 33.03, 33.05, 33.06, 33.08, 33.17,
#        33.16, 33.15, 33.1 , 33.11, 33.18, 33.14, 33.21, 33.23, 33.22,
#        33.25, 33.31, 33.29, 33.39, 33.37, 33.27, 35.69, 35.56, 35.29,
#        35.25, 35.11, 35.18, 35.02, 35.46, 37.45, 37.24, 34.93, 34.97,
#        37.22, 37.15, 37.14, 40.56, 40.61, 40.64, 40.52, 40.53, 40.49,
#        40.71, 40.68, 40.46, 40.4 , 40.39, 40.82, 39.56, 39.63, 41.86,
#        41.66, 41.6 , 41.7 , 41.69, 41.72, 41.63, 41.53, 41.48, 41.46,
#        41.26, 41.43, 41.41, 41.38, 41.28, 41.21, 41.23, 41.2 , 41.5 ,
#        40.09, 40.2 , 40.34, 40.32, 40.18, 40.15, 40.07, 40.03, 39.94,
#        39.91, 41.15, 36.39, 36.22, 36.23, 36.12, 35.82, 35.9 , 36.05,
#        36.07, 35.97, 35.96, 35.86, 35.85, 35.89, 35.88])

# %%
houses['ocean_proximity'].value_counts() / len(houses) *100
# Out:
# <1H OCEAN     44.263566
# INLAND        31.739341
# NEAR OCEAN    12.877907
# NEAR BAY      11.094961
# ISLAND         0.024225
# Name: ocean_proximity, dtype: float64

# %% [markdown]
# Como podemos comprobar esta es una función que tiene un mayor impacto en variables categóricas, ya por lo general, las variables numéricas tienen demasiados valores diferentes.

# %% [markdown]
# ### Resumen estadístico

# %%
houses.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
# Resumen estadístico.
houses.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
houses[(houses.total_rooms <= 5692)].describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  19351.000000  19351.000000        19351.000000  19351.000000
# mean    -119.590717     35.647030           29.522764   2224.760322
# std        2.000693      2.142488           12.308959   1153.427276
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.810000     33.940000           19.000000   1406.000000
# 50%     -118.500000     34.260000           30.000000   2036.000000
# 75%     -118.030000     37.720000           38.000000   2892.000000
# max     -114.310000     41.950000           52.000000   5692.000000
#
#        total_bedrooms    population    households  median_income  \
# count    19155.000000  19351.000000  19351.000000   19351.000000
# mean       463.442339   1244.378172    433.378430       3.812826
# std        254.263488    711.374657    235.044274       1.883625
# min          1.000000      3.000000      1.000000       0.499900
# 25%        288.000000    766.000000    272.000000       2.527650
# 50%        416.000000   1118.000000    392.000000       3.481200
# 75%        594.000000   1591.000000    557.000000       4.669050
# max       2610.000000   8733.000000   2406.000000      15.000100
#
#        median_house_value
# count        19351.000000
# mean        204969.065371
# std         115286.167632
# min          14999.000000
# 25%         117600.000000
# 50%         177800.000000
# 75%         262250.000000
# max         500001.000000

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
houses.describe(include = "object")
# Out:
#        ocean_proximity
# count            20640
# unique               5
# top          <1H OCEAN
# freq              9136

# %%
houses.describe(include = "all")
# Out:
#            longitude      latitude  housing_median_age   total_rooms  \
# count   20640.000000  20640.000000        20640.000000  20640.000000
# unique           NaN           NaN                 NaN           NaN
# top              NaN           NaN                 NaN           NaN
# freq             NaN           NaN                 NaN           NaN
# mean     -119.569704     35.631861           28.639486   2635.763081
# std         2.003532      2.135952           12.585558   2181.615252
# min      -124.350000     32.540000            1.000000      2.000000
# 25%      -121.800000     33.930000           18.000000   1447.750000
# 50%      -118.490000     34.260000           29.000000   2127.000000
# 75%      -118.010000     37.710000           37.000000   3148.000000
# max      -114.310000     41.950000           52.000000  39320.000000
#
#         total_bedrooms    population    households  median_income  \
# count     20433.000000  20640.000000  20640.000000   20640.000000
# unique             NaN           NaN           NaN            NaN
# top                NaN           NaN           NaN            NaN
# freq               NaN           NaN           NaN            NaN
# mean        537.870553   1425.476744    499.539680       3.870671
# std         421.385070   1132.462122    382.329753       1.899822
# min           1.000000      3.000000      1.000000       0.499900
# 25%         296.000000    787.000000    280.000000       2.563400
# 50%         435.000000   1166.000000    409.000000       3.534800
# 75%         647.000000   1725.000000    605.000000       4.743250
# max        6445.000000  35682.000000   6082.000000      15.000100
#
#         median_house_value ocean_proximity
# count         20640.000000           20640
# unique                 NaN               5
# top                    NaN       <1H OCEAN
# freq                   NaN            9136
# mean         206855.816909             NaN
# std          115395.615874             NaN
# min           14999.000000             NaN
# 25%          119600.000000             NaN
# 50%          179700.000000             NaN
# 75%          264725.000000             NaN
# max          500001.000000             NaN

# %% [markdown]
# Es interesante observar que el resumen estadístico descarta automáticamente cualquier variable que no sea numérica.

# %%
houses.describe()["total_rooms"]["mean"]
# Out:
# 2635.7630813953488

# %% [markdown]
# ### Media de una columna

# %%
print('Media de la variable total rooms', round(houses['total_rooms'].mean(), 3))
print('Media de la variable total bedrooms', round(houses['total_bedrooms'].mean(), 3))
# Out:
# Media de la variable total rooms 2635.763
# Media de la variable total bedrooms 537.871

# %% [markdown]
# ### Copia de un dataframe
#
# Al igual que en listas y arrays los dataframes comparten memoria. Es fácil equivocarnos y asignar a una nueva variable un dataframe completo, posteriormente, en esta nueva variable realizar modificaciones, pensando que sólamente las estamos realizando en la copia del dataframe, pero no es así, estamos realizando modificaciones en ambos dataframes ya que al estar almacenados en memoria, comparten las mismas posiciones, veamos un ejemplo de como NO copiar un dataframe.

# %%
import numpy as np

bad_copy = houses

# Modificamos la primera fila por ceros
bad_copy.iloc[[0]] = np.zeros(len(houses.columns))

bad_copy.head(3)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       0.00      0.00                 0.0          0.0             0.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         0.0         0.0         0.0000                 0.0             0.0
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY

# %% [markdown]
# Observamos que los cambios se reflejan en el dataframe original

# %%
houses.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       0.00      0.00                 0.0          0.0             0.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         0.0         0.0         0.0000                 0.0             0.0
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY

# %% [markdown]
# Por lo tanto, hemos modificado ambos dataframes, para únicamente realizar modificaciones sobre la copia, hemos de hacer uso del comando <code>.copy</code>

# %%
houses = pd.read_csv('housing_California.csv')

# Copiamos correctamente el dataframe
df_copia = houses.copy()

df_copia.iloc[[0]] = np.zeros(len(houses.columns))

df_copia.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       0.00      0.00                 0.0          0.0             0.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         0.0         0.0         0.0000                 0.0             0.0
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY

# %%
houses.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY

# %% [markdown]
# ### Correlaciones de las variables numéricas

# %%
houses.corr().style.background_gradient(cmap = "coolwarm")
# Out:
# <style type="text/css">
# #T_0bb8c_row0_col0, #T_0bb8c_row1_col1, #T_0bb8c_row2_col2, #T_0bb8c_row3_col3, #T_0bb8c_row4_col4, #T_0bb8c_row5_col5, #T_0bb8c_row6_col6, #T_0bb8c_row7_col7, #T_0bb8c_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_0bb8c_row0_col1, #T_0bb8c_row1_col0, #T_0bb8c_row1_col8, #T_0bb8c_row2_col3, #T_0bb8c_row2_col4, #T_0bb8c_row2_col5, #T_0bb8c_row2_col6, #T_0bb8c_row2_col7, #T_0bb8c_row3_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_0bb8c_row0_col2 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_0bb8c_row0_col3 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_0bb8c_row0_col4 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_0bb8c_row0_col5 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_0bb8c_row0_col6, #T_0bb8c_row1_col2 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_0bb8c_row0_col7 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_0bb8c_row0_col8 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_0bb8c_row1_col3 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_0bb8c_row1_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_0bb8c_row1_col5 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_0bb8c_row1_col6, #T_0bb8c_row7_col2 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_0bb8c_row1_col7 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_0bb8c_row2_col0, #T_0bb8c_row5_col1 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_0bb8c_row2_col1 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_0bb8c_row2_col8 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_0bb8c_row3_col0 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_0bb8c_row3_col1 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_0bb8c_row3_col4, #T_0bb8c_row4_col3 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_0bb8c_row3_col5 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_0bb8c_row3_col6 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_0bb8c_row3_col7, #T_0bb8c_row8_col6 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_0bb8c_row3_col8, #T_0bb8c_row7_col6 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_0bb8c_row4_col0 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_0bb8c_row4_col1 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_0bb8c_row4_col2 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_0bb8c_row4_col5 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_0bb8c_row4_col6, #T_0bb8c_row6_col4 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_0bb8c_row4_col7 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_0bb8c_row4_col8 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_0bb8c_row5_col0 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_0bb8c_row5_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_0bb8c_row5_col3 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_0bb8c_row5_col4 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_0bb8c_row5_col6, #T_0bb8c_row6_col5 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_0bb8c_row5_col7 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_0bb8c_row5_col8 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_0bb8c_row6_col0 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_0bb8c_row6_col1 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_0bb8c_row6_col2 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_0bb8c_row6_col3 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_0bb8c_row6_col7 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_0bb8c_row6_col8 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_0bb8c_row7_col0 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_0bb8c_row7_col1 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_0bb8c_row7_col3 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_0bb8c_row7_col4 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_0bb8c_row7_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_0bb8c_row7_col8 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_0bb8c_row8_col0 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_0bb8c_row8_col1 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_0bb8c_row8_col2 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_0bb8c_row8_col3 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_0bb8c_row8_col4 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_0bb8c_row8_col5 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_0bb8c_row8_col7 {
#   background-color: #f6a586;
#   color: #000000;
# }
# </style>
# <table id="T_0bb8c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >longitude</th>
#       <th class="col_heading level0 col1" >latitude</th>
#       <th class="col_heading level0 col2" >housing_median_age</th>
#       <th class="col_heading level0 col3" >total_rooms</th>
#       <th class="col_heading level0 col4" >total_bedrooms</th>
#       <th class="col_heading level0 col5" >population</th>
#       <th class="col_heading level0 col6" >households</th>
#       <th class="col_heading level0 col7" >median_income</th>
#       <th class="col_heading level0 col8" >median_house_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0bb8c_level0_row0" class="row_heading level0 row0" >longitude</th>
#       <td id="T_0bb8c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_0bb8c_row0_col1" class="data row0 col1" >-0.924664</td>
#       <td id="T_0bb8c_row0_col2" class="data row0 col2" >-0.108197</td>
#       <td id="T_0bb8c_row0_col3" class="data row0 col3" >0.044568</td>
#       <td id="T_0bb8c_row0_col4" class="data row0 col4" >0.069608</td>
#       <td id="T_0bb8c_row0_col5" class="data row0 col5" >0.099773</td>
#       <td id="T_0bb8c_row0_col6" class="data row0 col6" >0.055310</td>
#       <td id="T_0bb8c_row0_col7" class="data row0 col7" >-0.015176</td>
#       <td id="T_0bb8c_row0_col8" class="data row0 col8" >-0.045967</td>
#     </tr>
#     <tr>
#       <th id="T_0bb8c_level0_row1" class="row_heading level0 row1" >latitude</th>
#       <td id="T_0bb8c_row1_col0" class="data row1 col0" >-0.924664</td>
#       <td id="T_0bb8c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_0bb8c_row1_col2" class="data row1 col2" >0.011173</td>
#       <td id="T_0bb8c_row1_col3" class="data row1 col3" >-0.036100</td>
#       <td id="T_0bb8c_row1_col4" class="data row1 col4" >-0.066983</td>
#       <td id="T_0bb8c_row1_col5" class="data row1 col5" >-0.108785</td>
#       <td id="T_0bb8c_row1_col6" class="data row1 col6" >-0.071035</td>
#       <td id="T_0bb8c_row1_col7" class="data row1 col7" >-0.079809</td>
#       <td id="T_0bb8c_row1_col8" class="data row1 col8" >-0.144160</td>
#     </tr>
#     <tr>
#       <th id="T_0bb8c_level0_row2" class="row_heading level0 row2" >housing_median_age</th>
#       <td id="T_0bb8c_row2_col0" class="data row2 col0" >-0.108197</td>
#       <td id="T_0bb8c_row2_col1" class="data row2 col1" >0.011173</td>
#       <td id="T_0bb8c_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_0bb8c_row2_col3" class="data row2 col3" >-0.361262</td>
#       <td id="T_0bb8c_row2_col4" class="data row2 col4" >-0.320451</td>
#       <td id="T_0bb8c_row2_col5" class="data row2 col5" >-0.296244</td>
#       <td id="T_0bb8c_row2_col6" class="data row2 col6" >-0.302916</td>
#       <td id="T_0bb8c_row2_col7" class="data row2 col7" >-0.119034</td>
#       <td id="T_0bb8c_row2_col8" class="data row2 col8" >0.105623</td>
#     </tr>
#     <tr>
#       <th id="T_0bb8c_level0_row3" class="row_heading level0 row3" >total_rooms</th>
#       <td id="T_0bb8c_row3_col0" class="data row3 col0" >0.044568</td>
#       <td id="T_0bb8c_row3_col1" class="data row3 col1" >-0.036100</td>
#       <td id="T_0bb8c_row3_col2" class="data row3 col2" >-0.361262</td>
#       <td id="T_0bb8c_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_0bb8c_row3_col4" class="data row3 col4" >0.930380</td>
#       <td id="T_0bb8c_row3_col5" class="data row3 col5" >0.857126</td>
#       <td id="T_0bb8c_row3_col6" class="data row3 col6" >0.

# %%
houses.iloc[np.random.randint(0, 20640, 
                              int(len(houses)* 0.2))]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13937    -117.27     34.24                34.0       3687.0           756.0
# 419      -122.26     37.89                52.0       3078.0           494.0
# 15978    -122.46     37.76                52.0       1817.0           449.0
# 4536     -118.21     34.03                52.0        497.0           132.0
# 14562    -117.22     32.83                31.0       2558.0           512.0
# ...          ...       ...                 ...          ...             ...
# 19148    -122.69     38.34                15.0       3091.0           697.0
# 14192    -117.07     32.69                20.0       2192.0           406.0
# 9839     -121.92     36.61                27.0       1619.0           352.0
# 16368    -121.31     38.01                22.0       2101.0           514.0
# 8367     -118.35     33.98                33.0       1884.0           477.0
#
#        population  households  median_income  median_house_value  \
# 13937       941.0       367.0         2.8750            117600.0
# 419        1005.0       462.0         6.3810            342200.0
# 15978       948.0       380.0         3.9300            390000.0
# 4536        547.0       121.0         2.2083            146300.0
# 14562      1164.0       492.0         3.4318            200400.0
# ...           ...         ...            ...                 ...
# 19148      1602.0       682.0         4.0071            135500.0
# 14192      1766.0       393.0         4.0921            135000.0
# 9839        831.0       344.0         4.3000            226400.0
# 16368      1304.0       511.0         2.8348            101600.0
# 8367       1518.0       449.0         3.1194            152800.0
#
#       ocean_proximity
# 13937          INLAND
# 419          NEAR BAY
# 15978        NEAR BAY
# 4536        <1H OCEAN
# 14562      NEAR OCEAN
# ...               ...
# 19148       <1H OCEAN
# 14192      NEAR OCEAN
# 9839       NEAR OCEAN
# 16368          INLAND
# 8367        <1H OCEAN
#
# [4128 rows x 10 columns]

# %% [markdown]
# Nótese que automáticamente toma todas las variables numéricas.

# %% [markdown]
# ### Nombres de las columnas de un dataframe

# %%
houses.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
houses.columns[3]
# Out:
# 'total_rooms'

# %% [markdown]
# Las columnas de un dataframe pueden trabajarse como listas

# %% [markdown]
# ### Borrar duplicados de un dataframe

# %%
# Para verlo más claro, vamos a realizar una copia de las diez primeras posiciones del data frame
ten_rows = houses.head(10).copy()

# %%
# Duplicamos la fila 9 varias veces
ten_rows = ten_rows.append(ten_rows.iloc[[9]])
ten_rows = ten_rows.append(ten_rows.iloc[[9]])
ten_rows = ten_rows.append(ten_rows.iloc[[9]])
ten_rows = ten_rows.append(ten_rows.iloc[[9]])
ten_rows = ten_rows.append(ten_rows.iloc[[9]])

# %%
ten_rows
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
# 9    -122.25     37.84                52.0       3549.0           707.0
# 9    -122.25     37.84                52.0       3549.0           707.0
# 9    -122.25     37.84                52.0       3549.0           707.0
# 9    -122.25     37.84                52.0       3549.0           707.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
# 5       413.0       193.0         4.0368            269700.0        NEAR BAY
# 6      1094.0       514.0         3.6591            299200.0        NEAR BAY
# 7      1157.0       647.0         3.1200            241400.0        NEAR BAY
# 8      1206.0       595.0         2.0804            226700.0        NEAR BAY
# 9      1551.0       714.0         3.6912            261100.0        NEAR BAY
# 9      1551.0       714.0         3.6912            261100.0        NEAR BAY
# 9      1551.0       714.0         3.6912            261100.0        NEAR BAY
# 9      1551.0       714.0         3.6912            261100.0        NEAR BAY
# 9      1551.0       714.0         3.6912            261100.0        NEAR BAY
# 9      1551.0       714.0         3.6912            261100.0        NEAR BAY

# %%
ten_rows = ten_rows.drop_duplicates(inplace = False, keep = 'first')
ten_rows
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
# 5       413.0       193.0         4.0368            269700.0        NEAR BAY
# 6      1094.0       514.0         3.6591            299200.0        NEAR BAY
# 7      1157.0       647.0         3.1200            241400.0        NEAR BAY
# 8      1206.0       595.0         2.0804            226700.0        NEAR BAY
# 9      1551.0       714.0         3.6912            261100.0        NEAR BAY

# %%
# Para verlo más claro, vamos a realizar una copia de las diez primeras posiciones del data frame
ten_rows = houses.head(10).copy()

# Duplicamos la fila 9 varias veces
ten_rows = ten_rows.append(ten_rows.iloc[[9]])
ten_rows = ten_rows.append(ten_rows.iloc[[9]])
ten_rows = ten_rows.append(ten_rows.iloc[[9]])
ten_rows = ten_rows.append(ten_rows.iloc[[9]])
ten_rows = ten_rows.append(ten_rows.iloc[[9]])

ten_rows.drop_duplicates(inplace = True, keep = 'first')
ten_rows
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
# 5       413.0       193.0         4.0368            269700.0        NEAR BAY
# 6      1094.0       514.0         3.6591            299200.0        NEAR BAY
# 7      1157.0       647.0         3.1200            241400.0        NEAR BAY
# 8      1206.0       595.0         2.0804            226700.0        NEAR BAY
# 9      1551.0       714.0         3.6912            261100.0        NEAR BAY

# %%
# Para verlo más claro, vamos a realizar una copia de las diez primeras posiciones del data frame
ten_rows = houses.head(10).copy()

# Duplicamos la fila 9 varias veces
ten_rows = ten_rows.append(ten_rows.iloc[[9]])
ten_rows = ten_rows.append(ten_rows.iloc[[9]])
ten_rows = ten_rows.append(ten_rows.iloc[[9]])
ten_rows = ten_rows.append(ten_rows.iloc[[9]])
ten_rows = ten_rows.append(ten_rows.iloc[[9]])

ten_rows = ten_rows.drop_duplicates(inplace = True, keep = 'first')
ten_rows

# %% [markdown]
# Con el parámetro `inplace` **siempre que aparezca este parámetro**.
# * Si utilizas `inplace = True` **NO** creas una nueva variable.
# * Si utilizas `inplace = Flase` tienes que crear una nueva variable.

# %% [markdown]
# ### Uso de RAM para un dataframe

# %%
# Consumo RAM del dataframe en BYTES
houses.memory_usage()
# Out:
# Index                    128
# longitude             165120
# latitude              165120
# housing_median_age    165120
# total_rooms           165120
# total_bedrooms        165120
# population            165120
# households            165120
# median_income         165120
# median_house_value    165120
# ocean_proximity       165120
# dtype: int64

# %% [markdown]
# ### Análisis gráfico con scatter matrix

# %%
# Configuración para mostrar gráficas en notebook
# %pylab
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# Importamos scatter_matrix
from pandas.plotting import scatter_matrix
# Out:
# Using matplotlib backend: <object object at 0x000001B14E3F7C80>
# Populating the interactive namespace from numpy and matplotlib

# %%
# Es necesario que configuremos el tamaño de las gráficas que será el mismo que el número de columnas
scatter_matrix(houses, 
               
               figsize = (len(houses.columns), len(houses.columns)), 
               
               diagonal = 'kde')
# Out:
# array([[<AxesSubplot:xlabel='longitude', ylabel='longitude'>,
#         <AxesSubplot:xlabel='latitude', ylabel='longitude'>,
#         <AxesSubplot:xlabel='housing_median_age', ylabel='longitude'>,
#         <AxesSubplot:xlabel='total_rooms', ylabel='longitude'>,
#         <AxesSubplot:xlabel='total_bedrooms', ylabel='longitude'>,
#         <AxesSubplot:xlabel='population', ylabel='longitude'>,
#         <AxesSubplot:xlabel='households', ylabel='longitude'>,
#         <AxesSubplot:xlabel='median_income', ylabel='longitude'>,
#         <AxesSubplot:xlabel='median_house_value', ylabel='longitude'>],
#        [<AxesSubplot:xlabel='longitude', ylabel='latitude'>,
#         <AxesSubplot:xlabel='latitude', ylabel='latitude'>,
#         <AxesSubplot:xlabel='housing_median_age', ylabel='latitude'>,
#         <AxesSubplot:xlabel='total_rooms', ylabel='latitude'>,
#         <AxesSubplot:xlabel='total_bedrooms', ylabel='latitude'>,
#         <AxesSubplot:xlabel='population', ylabel='latitude'>,
#         <AxesSubplot:xlabel='households', ylabel='latitude'>,
#         <AxesSubplot:xlabel='median_income', ylabel='latitude'>,
#         <AxesSubplot:xlabel='median_house_value', ylabel='latitude'>],
#        [<AxesSubplot:xlabel='longitude', ylabel='housing_median_age'>,
#         <AxesSubplot:xlabel='latitude', ylabel='housing_median_age'>,
#         <AxesSubplot:xlabel='housing_median_age', ylabel='housing_median_age'>,
#         <AxesSubplot:xlabel='total_rooms', ylabel='housing_median_age'>,
#         <AxesSubplot:xlabel='total_bedrooms', ylabel='housing_median_age'>,
#         <AxesSubplot:xlabel='population', ylabel='housing_median_age'>,
#         <AxesSubplot:xlabel='households', ylabel='housing_median_age'>,
#         <AxesSubplot:xlabel='median_income', ylabel='housing_median_age'>,
#         <AxesSubplot:xlabel='median_house_value', ylabel='housing_median_age'>],
#        [<AxesSubplot:xlabel='longitude', ylabel='total_rooms'>,
#         <AxesSubplot:xlabel='latitude', ylabel='total_rooms'>,
#         <AxesSubplot:xlabel='housing_median_age', ylabel='total_rooms'>,
#         <AxesSubplot:xlabel='total_rooms', ylabel='total_rooms'>,
#         <AxesSubplot:xlabel='total_bedrooms', ylabel='total_rooms'>,
#         <AxesSubplot:xlabel='population', ylabel='total_rooms'>,
#         <AxesSubplot:xlabel='households', ylabel='total_rooms'>,
#         <AxesSubplot:xlabel='median_income', ylabel='total_rooms'>,
#         <AxesSubplot:xlabel='median_house_value', ylabel='total_rooms'>],
#        [<AxesSubplot:xlabel='longitude', ylabel='total_bedrooms'>,
#         <AxesSubplot:xlabel='latitude', ylabel='total_bedrooms'>,
#         <AxesSubplot:xlabel='housing_median_age', ylabel='total_bedrooms'>,
#         <AxesSubplot:xlabel='total_rooms', ylabel='total_bedrooms'>,
#         <AxesSubplot:xlabel='total_bedrooms', ylabel='total_bedrooms'>,
#         <AxesSubplot:xlabel='population', ylabel='total_bedrooms'>,
#         <AxesSubplot:xlabel='households', ylabel='total_bedrooms'>,
#         <AxesSubplot:xlabel='median_income', ylabel='total_bedrooms'>,
#         <AxesSubplot:xlabel='median_house_value', ylabel='total_bedrooms'>],
#        [<AxesSubplot:xlabel='longitude', ylabel='population'>,
#         <AxesSubplot:xlabel='latitude', ylabel='population'>,
#         <AxesSubplot:xlabel='housing_median_age', ylabel='population'>,
#         <AxesSubplot:xlabel='total_rooms', ylabel='population'>,
#         <AxesSubplot:xlabel='total_bedrooms', ylabel='population'>,
#         <AxesSubplot:xlabel='population', ylabel='population'>,
#         <AxesSubplot:xlabel='households', ylabel='population'>,
#         <AxesSubplot:xlabel='median_income', ylabel='population'>,
#         <AxesSubplot:xlabel='median_house_value', ylabel='population'>],
#        [<AxesSubplot:xlabel='longitude', ylabel='households'>,
#         <AxesSubplot:xlabel='latitude', ylabel='households'>,
#         <AxesSubplot:xlabel='housing_median_age', ylabel='households'>,
#         <AxesSubplot:xlabel='total_rooms', ylabel='households'>,
#         <AxesSubplot:xlabel='total_bedrooms', ylabel='households'>,
#         <AxesSubplot:xlabel='population', ylabel='households'>,
#         <AxesSubplot:xlabel='households', ylabel='households'>,
#         <AxesSubplot:xlabel='median_income', ylabel='households'>,
#         <AxesSubplot:xlabel='median_house_value', ylabel='households'>],
#        [<AxesSubplot:xlabel='longitude', ylabel='median_income'>,
#         <AxesSubplot:xlabel='latitude', ylabel='median_income'>,
#         <AxesSubplot:xlabel='housing_median_age', ylabel='median_income'>,
#         <AxesSubplot:xlabel='total_rooms', ylabel='median_income'>,
#         <AxesSubplot:xlabel='total_bedrooms', ylabel='median_income'>,
#         <AxesSubplot:xlabel='population', ylabel='median_income'>,
#         <AxesSubplot:xlabel='households', ylabel='median_income'>,
#         <AxesSubplot:xlabel='median_income', ylabel='median_income'>,
#         <AxesSubplot:xlabel='median_house_value', ylabel='median_income'>],
#        [<AxesSubplot:xlabel='longitude', ylabel='median_house_value'>,
#         <AxesSubplot:xlabel='latitude', ylabel='median_house_value'>,
#         <AxesSubplot:xlabel='housing_median_age', ylabel='median_house_value'>,
#         <AxesSubplot:xlabel='total_rooms', ylabel='median_house_value'>,
#         <AxesSubplot:xlabel='total_bedrooms', ylabel='median_house_value'>,
#         <AxesSubplot:xlabel='population', ylabel='median_house_value'>,
#         <AxesSubplot:xlabel='households', ylabel='median_house_value'>,
#         <AxesSubplot:xlabel='median_income', ylabel='median_house_value'>,
#         <AxesSubplot:xlabel='median_house_value', ylabel='median_house_value'>]],
#       dtype=object)

# %% [markdown]
# ### Histogramas de las variables numéricas

# %%
# Histogramas de cada variable continua del dataframe.
houses.hist(figsize = (len(houses.columns), len(houses.columns)))
# Out:
# array([[<AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'latitude'}>,
#         <AxesSubplot:title={'center':'housing_median_age'}>],
#        [<AxesSubplot:title={'center':'total_rooms'}>,
#         <AxesSubplot:title={'center':'total_bedrooms'}>,
#         <AxesSubplot:title={'center':'population'}>],
#        [<AxesSubplot:title={'center':'households'}>,
#         <AxesSubplot:title={'center':'median_income'}>,
#         <AxesSubplot:title={'center':'median_house_value'}>]],
#       dtype=object)

# %%
houses_copia = houses.copy()

houses_copia = houses_copia[(houses_copia.total_rooms < 20000)]

# Histogramas de cada variable continua del dataframe.
houses_copia.hist(figsize = (len(houses.columns), len(houses.columns)))
# Out:
# array([[<AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'latitude'}>,
#         <AxesSubplot:title={'center':'housing_median_age'}>],
#        [<AxesSubplot:title={'center':'total_rooms'}>,
#         <AxesSubplot:title={'center':'total_bedrooms'}>,
#         <AxesSubplot:title={'center':'population'}>],
#        [<AxesSubplot:title={'center':'households'}>,
#         <AxesSubplot:title={'center':'median_income'}>,
#         <AxesSubplot:title={'center':'median_house_value'}>]],
#       dtype=object)

# %%
np.quantile(houses.total_rooms, .95)
# Out:
# 6213.199999999997

# %% [markdown]
# ### Cambiando el tipo de las variables.
#
# Con la función `info` podemos obtener la información del tipo de variables.

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# Como podemos comprobar, todas las variables son de tipo float, excepto ocean_proximity que es de tipo object, cuando la realidad es que esto, no es así, algunas de las transformaciones más importantes que podemos realizar en un dataframe sobre sus variables es cambiarles el tipo, es decir que pasen a ser categóricas o tipo fecha, vamos a ver cómo cambiar a tipo categórica las variables de un dataframe.
#
# Una de las posibles formas de cambiar el tipo de una variable es a través de `pd.Categorical`

# %%
houses["ocean_proximity"] = pd.Categorical(houses["ocean_proximity"])

# %% [markdown]
# Mostramos la información del dataframe de nuevo

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  category
# dtypes: category(1), float64(9)
# memory usage: 1.4 MB

# %% [markdown]
# Ahora, podemos mostrar un resumen estadístico solamente de las variables categóricas

# %%
# houses.describe(include='object')

# %%
houses.describe(include='category')
# Out:
#        ocean_proximity
# count            20640
# unique               5
# top          <1H OCEAN
# freq              9136

# %% [markdown]
# ### AGRUPACIÓN DE DATAFRAMES - GROUP BY
#
# Al igual que en SQL, desde Python también podemos realizar agrupaciones de nuestros datos con la función __<code>groupby</code>__

# %%
# Agrupamos por la media de los valores numéricos para la columna ocean_proximity
houses.groupby(['ocean_proximity']).mean()
# Out:
#                   longitude   latitude  housing_median_age  total_rooms  \
# ocean_proximity
# <1H OCEAN       -118.847766  34.560577           29.279225  2628.343586
# INLAND          -119.732990  36.731829           24.271867  2717.742787
# ISLAND          -118.354000  33.358000           42.400000  1574.600000
# NEAR BAY        -122.260694  37.801057           37.730131  2493.589520
# NEAR OCEAN      -119.332555  34.738439           29.347254  2583.700903
#
#                  total_bedrooms   population  households  median_income  \
# ocean_proximity
# <1H OCEAN            546.539185  1520.290499  517.744965       4.230682
# INLAND               533.881619  1391.046252  477.447565       3.208996
# ISLAND               420.400000   668.000000  276.600000       2.744420
# NEAR BAY             514.182819  1230.317467  488.616157       4.172885
# NEAR OCEAN           538.615677  1354.008653  501.244545       4.005785
#
#                  median_house_value
# ocean_proximity
# <1H OCEAN             240084.285464
# INLAND                124805.392001
# ISLAND                380440.000000
# NEAR BAY              259212.311790
# NEAR OCEAN            249433.977427

# %%
# Observamos cuántos tipos el total de dormitorios en función de
# su frecuencia.
houses.groupby(['total_bedrooms']).count()
# Out:
#                 longitude  latitude  housing_median_age  total_rooms  \
# total_bedrooms
# 1.0                     1         1                   1            1
# 2.0                     2         2                   2            2
# 3.0                     5         5                   5            5
# 4.0                     7         7                   7            7
# 5.0                     6         6                   6            6
# ...                   ...       ...                 ...          ...
# 5290.0                  1         1                   1            1
# 5419.0                  1         1                   1            1
# 5471.0                  1         1                   1            1
# 6210.0                  1         1                   1            1
# 6445.0                  1         1                   1            1
#
#                 population  households  median_income  median_house_value  \
# total_bedrooms
# 1.0                      1           1              1                   1
# 2.0                      2           2              2                   2
# 3.0                      5           5              5                   5
# 4.0                      7           7              7                   7
# 5.0                      6           6              6                   6
# ...                    ...         ...            ...                 ...
# 5290.0                   1           1              1                   1
# 5419.0                   1           1              1                   1
# 5471.0                   1           1              1                   1
# 6210.0                   1           1              1                   1
# 6445.0                   1           1              1                   1
#
#                 ocean_proximity
# total_bedrooms
# 1.0                           1
# 2.0                           2
# 3.0                           5
# 4.0                           7
# 5.0                           6
# ...                         ...
# 5290.0                        1
# 5419.0                        1
# 5471.0                        1
# 6210.0                        1
# 6445.0                        1
#
# [1923 rows x 9 columns]

# %%
houses.groupby(['total_bedrooms']).count()['ocean_proximity']
# Out:
# total_bedrooms
# 1.0       1
# 2.0       2
# 3.0       5
# 4.0       7
# 5.0       6
#          ..
# 5290.0    1
# 5419.0    1
# 5471.0    1
# 6210.0    1
# 6445.0    1
# Name: ocean_proximity, Length: 1923, dtype: int64

# %%
houses.total_bedrooms.value_counts()
# Out:
# 280.0     55
# 331.0     51
# 345.0     50
# 343.0     49
# 393.0     49
#           ..
# 2961.0     1
# 1915.0     1
# 1215.0     1
# 3298.0     1
# 1052.0     1
# Name: total_bedrooms, Length: 1923, dtype: int64

# %%
# Obtener el porcentaje de valores para una variable categórica
print(
    (pd.crosstab(index=houses["ocean_proximity"], columns="count"))/len(houses) * 100)
# Out:
# col_0                count
# ocean_proximity
# <1H OCEAN        44.263566
# INLAND           31.739341
# ISLAND            0.024225
# NEAR BAY         11.094961
# NEAR OCEAN       12.877907

# %%
houses.ocean_proximity.value_counts() / len(houses) * 100
# Out:
# <1H OCEAN     44.263566
# INLAND        31.739341
# NEAR OCEAN    12.877907
# NEAR BAY      11.094961
# ISLAND         0.024225
# Name: ocean_proximity, dtype: float64

# %% [markdown]
# ### MERGE DE DATAFRAMES
#
# En algunas ocasiones, vamos a necesitar unir dos o más datasets para ello, en primer lugar, al igual que con listas, podemos hacer uso de la función __<code>.append</code>__
#
# Debido a la dimensión de filas y columnas del dataframe, vamos a crear dos dataframes más reducidos para poder ejemplificar correctamente la función append.

# %%
# Creamos datasets reducidos
first_positions = houses[['housing_median_age', 
                             'total_rooms', 
                             'total_bedrooms']].head(5).copy()


last_positions = houses[['housing_median_age', 
                             'total_rooms', 
                             'total_bedrooms']].tail(4).copy()

print(first_positions.shape)
print(last_positions.shape)
# Out:
# (5, 3)
# (4, 3)

# %%
# Unimos ambos datasets con append
first_positions = first_positions.append(last_positions)

print(first_positions.shape)
# Out:
# (9, 3)

# %%
first_positions.reset_index(inplace=True, drop=True)

# %%
first_positions
# Out:
#    housing_median_age  total_rooms  total_bedrooms
# 0                41.0        880.0           129.0
# 1                21.0       7099.0          1106.0
# 2                52.0       1467.0           190.0
# 3                52.0       1274.0           235.0
# 4                52.0       1627.0           280.0
# 5                18.0        697.0           150.0
# 6                17.0       2254.0           485.0
# 7                18.0       1860.0           409.0
# 8                16.0       2785.0           616.0

# %% [markdown]
# Es importante que tengamos en cuenta con la presencia de nuevas columnas que aparezcan solamente en uno de los dataframes que vayamos a concatenar. Para ejemplificarlo, vamos a obtener de nuevo los datasets, dando una columna a más al dataset con las últimas posiciones.

# %%
# Creamos datasets reducidos
first_positions = houses[['housing_median_age', 
                             'total_rooms', 
                             'total_bedrooms']].head(5).copy()


last_positions = houses[['housing_median_age', 
                             'total_rooms', 
                             'total_bedrooms',
                             'households']].tail(4).copy()

print(first_positions.shape)
print(last_positions.shape)
# Out:
# (5, 3)
# (4, 4)

# %%
# Unimos ambos datasets con append
first_positions = first_positions.append(last_positions)

first_positions
# Out:
#        housing_median_age  total_rooms  total_bedrooms  households
# 0                    41.0        880.0           129.0         NaN
# 1                    21.0       7099.0          1106.0         NaN
# 2                    52.0       1467.0           190.0         NaN
# 3                    52.0       1274.0           235.0         NaN
# 4                    52.0       1627.0           280.0         NaN
# 20636                18.0        697.0           150.0       114.0
# 20637                17.0       2254.0           485.0       433.0
# 20638                18.0       1860.0           409.0       349.0
# 20639                16.0       2785.0           616.0       530.0

# %%
# El resumen estadístico se aplica solamente a las filas que existen
first_positions.describe()
# Out:
#        housing_median_age  total_rooms  total_bedrooms  households
# count            9.000000     9.000000         9.00000    4.000000
# mean            31.888889  2215.888889       400.00000  356.500000
# std             16.863010  1942.394556       311.05948  177.779826
# min             16.000000   697.000000       129.00000  114.000000
# 25%             18.000000  1274.000000       190.00000  290.250000
# 50%             21.000000  1627.000000       280.00000  391.000000
# 75%             52.000000  2254.000000       485.00000  457.250000
# max             52.000000  7099.000000      1106.00000  530.000000

# %% [markdown]
# En segundo lugar, podemos hacer uso de la función __<code>.concat</code>__. Es muy importante saber los tipos de unión ( _join_ ) que podemos realizar al concatenar datasets
# * __inner__: Se realiza la unión por los elementos comunes de ambos datasets.
# * __outer__: La unión se realiza por todos los elementos entre los datasets
#
# Se recomienda echar un vistazo a la documentación para ver los diferentes tipos de join que podemos realizar. https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html

# %% [markdown]
# Nota: Investigar la función `merge`: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html

# %%
first_positions = houses[['housing_median_age', 
                             'total_rooms', 
                             'total_bedrooms',
                             'ocean_proximity']].head(5).copy()


last_positions = houses[['housing_median_age', 
                             'total_rooms', 
                             'total_bedrooms',
                             'households',
                             'ocean_proximity']].tail(4).copy()

union_outer = pd.concat([first_positions, last_positions], 
                        ignore_index=True, join='outer')

union_outer
# Out:
#    housing_median_age  total_rooms  total_bedrooms ocean_proximity  households
# 0                41.0        880.0           129.0        NEAR BAY         NaN
# 1                21.0       7099.0          1106.0        NEAR BAY         NaN
# 2                52.0       1467.0           190.0        NEAR BAY         NaN
# 3                52.0       1274.0           235.0        NEAR BAY         NaN
# 4                52.0       1627.0           280.0        NEAR BAY         NaN
# 5                18.0        697.0           150.0          INLAND       114.0
# 6                17.0       2254.0           485.0          INLAND       433.0
# 7                18.0       1860.0           409.0          INLAND       349.0
# 8                16.0       2785.0           616.0          INLAND       530.0

# %%
union_inner = pd.concat([first_positions, last_positions], 
                        ignore_index=True, join='inner')

union_inner
# Out:
#    housing_median_age  total_rooms  total_bedrooms ocean_proximity
# 0                41.0        880.0           129.0        NEAR BAY
# 1                21.0       7099.0          1106.0        NEAR BAY
# 2                52.0       1467.0           190.0        NEAR BAY
# 3                52.0       1274.0           235.0        NEAR BAY
# 4                52.0       1627.0           280.0        NEAR BAY
# 5                18.0        697.0           150.0          INLAND
# 6                17.0       2254.0           485.0          INLAND
# 7                18.0       1860.0           409.0          INLAND
# 8                16.0       2785.0           616.0          INLAND

# %% [markdown]
# Compo podemos ver en el merge por tipo _inner_ la columna _households_ del nuevo dataset no aparece ya que no es un elemento común entre ambos datasets. No obstante hemos de tener en cuenta que si un dataset no tiene filas pertenecientes a una columna de otro dataset como es el caso de la columna _households_ que únicamente aparece en el nuevo dataset. Sus valores, pasarán a ser nulos.
#
# ### NUEVAS COLUMNAS
#
# En muchas ocasiones, vamos a necesitar añadir nuevas columnas a un dataframe o realizar modificaciones entre las columnas de un dataframe para obtener una nueva. Es importante saber que las operaciones se realizan de forma columnar, es decir, si dos columnas tienen una misma longitud podemos realizar una operación entre ambas si necesidad de iterara sobre sus filas.
#
# Para agregar una nueva columna simplemente podemos crear una nueva variable con el nombre del dataframe y el nombre de la columna que vamos a crear.

# %%
np.random.randint(65, 120, 10)
# Out:
# array([ 85,  96,  81,  65, 119,  98,  66,  91,  80, 119])

# %%
union_inner
# Out:
#    housing_median_age  total_rooms  total_bedrooms ocean_proximity
# 0                41.0        880.0           129.0        NEAR BAY
# 1                21.0       7099.0          1106.0        NEAR BAY
# 2                52.0       1467.0           190.0        NEAR BAY
# 3                52.0       1274.0           235.0        NEAR BAY
# 4                52.0       1627.0           280.0        NEAR BAY
# 5                18.0        697.0           150.0          INLAND
# 6                17.0       2254.0           485.0          INLAND
# 7                18.0       1860.0           409.0          INLAND
# 8                16.0       2785.0           616.0          INLAND

# %%
union_inner['area'] = np.random.randint(65, 120, len(union_inner))

print(union_inner.columns)
# Out:
# Index(['housing_median_age', 'total_rooms', 'total_bedrooms',
#        'ocean_proximity', 'area'],
#       dtype='object')

# %%
union_inner.head()
# Out:
#    housing_median_age  total_rooms  total_bedrooms ocean_proximity  area
# 0                41.0        880.0           129.0        NEAR BAY    78
# 1                21.0       7099.0          1106.0        NEAR BAY    79
# 2                52.0       1467.0           190.0        NEAR BAY   115
# 3                52.0       1274.0           235.0        NEAR BAY    73
# 4                52.0       1627.0           280.0        NEAR BAY    95

# %%
union_inner["area"] / houses["housing_median_age"]
# Out:
# 0        1.902439
# 1        3.761905
# 2        2.211538
# 3        1.403846
# 4        1.826923
#            ...
# 20635         NaN
# 20636         NaN
# 20637         NaN
# 20638         NaN
# 20639         NaN
# Length: 20640, dtype: float64

# %%
# Podemos crear una nueva columna que sea la media de camas por habitaciones totales

union_inner['mean_bedrooms'] = round(union_inner['total_rooms'] / union_inner['total_bedrooms'],2)

# %%
union_inner
# Out:
#    housing_median_age  total_rooms  total_bedrooms ocean_proximity  area  \
# 0                41.0        880.0           129.0        NEAR BAY    78
# 1                21.0       7099.0          1106.0        NEAR BAY    79
# 2                52.0       1467.0           190.0        NEAR BAY   115
# 3                52.0       1274.0           235.0        NEAR BAY    73
# 4                52.0       1627.0           280.0        NEAR BAY    95
# 5                18.0        697.0           150.0          INLAND    94
# 6                17.0       2254.0           485.0          INLAND    75
# 7                18.0       1860.0           409.0          INLAND    72
# 8                16.0       2785.0           616.0          INLAND   104
#
#    mean_bedrooms
# 0           6.82
# 1           6.42
# 2           7.72
# 3           5.42
# 4           5.81
# 5           4.65
# 6           4.65
# 7           4.55
# 8           4.52

# %% [markdown]
# ### BORRADO DE FILAS Y COLUMNAS
#
# En algunas ocasiones, cuando realicemos limpieza de datos o, porque no sean objeto de nuestro análisis vamos a necesitar borrar filas o columnas de un dataframe, para ambos casos la función es la misma __<code>.drop</code>__, si el borrado queremos realizarlo para filas usaremos en el parámetro __axis__ el valor 0 y para las columnas el valor 1.

# %%
union_inner = union_inner.drop(['housing_median_age', 'mean_bedrooms'], 
                               axis = 1)

union_inner
# Out:
#    total_rooms  total_bedrooms ocean_proximity  area
# 0        880.0           129.0        NEAR BAY    78
# 1       7099.0          1106.0        NEAR BAY    79
# 2       1467.0           190.0        NEAR BAY   115
# 3       1274.0           235.0        NEAR BAY    73
# 4       1627.0           280.0        NEAR BAY    95
# 5        697.0           150.0          INLAND    94
# 6       2254.0           485.0          INLAND    75
# 7       1860.0           409.0          INLAND    72
# 8       2785.0           616.0          INLAND   104

# %%
# Borrado por filas
print('TODAS LAS FILAS')
print(union_inner, "\n")

union_inner = union_inner.drop(3, axis=0)

print('BORRADO DE FILA 3')
print(union_inner.head(5))
# Out:
# TODAS LAS FILAS
#    total_rooms  total_bedrooms ocean_proximity  area
# 0        880.0           129.0        NEAR BAY    78
# 1       7099.0          1106.0        NEAR BAY    79
# 2       1467.0           190.0        NEAR BAY   115
# 3       1274.0           235.0        NEAR BAY    73
# 4       1627.0           280.0        NEAR BAY    95
# 5        697.0           150.0          INLAND    94
# 6       2254.0           485.0          INLAND    75
# 7       1860.0           409.0          INLAND    72
# 8       2785.0           616.0          INLAND   104
#
# BORRADO DE FILA 3
#    total_rooms  total_bedrooms ocean_proximity  area
# 0        880.0           129.0        NEAR BAY    78
# 1       7099.0          1106.0        NEAR BAY    79
# 2       1467.0           190.0        NEAR BAY   115
# 4       1627.0           280.0        NEAR BAY    95
# 5        697.0           150.0          INLAND    94

# %% [markdown]
# ### GESTIÓN DE NULOS
#
# Finalmente, como es habitual cuando trabajamos con dataframes pueden aparecer los _missing values_ o simplemente, valores nulos, en Python representados por el string __NaN__, mediante la función __<code>.isnull</code>__ podremos saber si un elemento de un dataframe es nulo o no, una práctica muy habitual es obtener el número de valores nulos por columna en un dataframe y su porcentaje.

# %%
print("*CANTIDAD de datos nulos por columna en el dataframe")
print(union_outer.isnull().sum())
print("----------------------------------")
print("*PORCENTAJE de datos nulos por columna en el dataframe")
print(union_outer.isnull().sum()/len(union_outer)*100)
# Out:
# *CANTIDAD de datos nulos por columna en el dataframe
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# ocean_proximity       0
# households            5
# dtype: int64
# ----------------------------------
# *PORCENTAJE de datos nulos por columna en el dataframe
# housing_median_age     0.000000
# total_rooms            0.000000
# total_bedrooms         0.000000
# ocean_proximity        0.000000
# households            55.555556
# dtype: float64

# %% [markdown]
# Si lo que queremos es reemplazar los valores nulos y no borrarlos haremos uso de la función __<code>.fillna</code>__

# %%
union_outer['households'] = union_outer['households'].fillna(5)

# %%
union_outer
# Out:
#    housing_median_age  total_rooms  total_bedrooms ocean_proximity  households
# 0                41.0        880.0           129.0        NEAR BAY         5.0
# 1                21.0       7099.0          1106.0        NEAR BAY         5.0
# 2                52.0       1467.0           190.0        NEAR BAY         5.0
# 3                52.0       1274.0           235.0        NEAR BAY         5.0
# 4                52.0       1627.0           280.0        NEAR BAY         5.0
# 5                18.0        697.0           150.0          INLAND       114.0
# 6                17.0       2254.0           485.0          INLAND       433.0
# 7                18.0       1860.0           409.0          INLAND       349.0
# 8                16.0       2785.0           616.0          INLAND       530.0

# %%
print("*CANTIDAD de datos nulos por columna en el data frame")
print(union_outer.isnull().sum())
# Out:
# *CANTIDAD de datos nulos por columna en el data frame
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# ocean_proximity       0
# households            0
# dtype: int64

# %% [markdown]
# Por el contrario, si lo que queremos es borrar los valores nulos de un dataframe podemos hacer uso de la función __<code>.dropna</code>__

# %%
union_outer = pd.concat([first_positions, last_positions], 
                        ignore_index=True, join='outer', sort=False)
union_outer
# Out:
#    housing_median_age  total_rooms  total_bedrooms ocean_proximity  households
# 0                41.0        880.0           129.0        NEAR BAY         NaN
# 1                21.0       7099.0          1106.0        NEAR BAY         NaN
# 2                52.0       1467.0           190.0        NEAR BAY         NaN
# 3                52.0       1274.0           235.0        NEAR BAY         NaN
# 4                52.0       1627.0           280.0        NEAR BAY         NaN
# 5                18.0        697.0           150.0          INLAND       114.0
# 6                17.0       2254.0           485.0          INLAND       433.0
# 7                18.0       1860.0           409.0          INLAND       349.0
# 8                16.0       2785.0           616.0          INLAND       530.0

# %%
union_outer = union_outer.dropna()

print("*CANTIDAD de datos nulos por columna en el data frame")
print(union_outer.isnull().sum())

print(union_outer.shape)
# Out:
# *CANTIDAD de datos nulos por columna en el data frame
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# ocean_proximity       0
# households            0
# dtype: int64
# (4, 5)

# %%
union_outer
# Out:
#    housing_median_age  total_rooms  total_bedrooms ocean_proximity  households
# 5                18.0        697.0           150.0          INLAND       114.0
# 6                17.0       2254.0           485.0          INLAND       433.0
# 7                18.0       1860.0           409.0          INLAND       349.0
# 8                16.0       2785.0           616.0          INLAND       530.0

# %% [markdown]
# ### Escribiendo dataframe como csv
#
# Al igual que podemos cargar datos de diferentes fuentes de datos y procesarlos como un dataframe, también podemos posteriormente escribir un dataframe en una de las múltiples fuentes que acepta pandas para exportar archivos, en esta ocasión, volcaremos la información de un dataframe como un .csv, para ello, disponemos de la función <code>**to_csv**</code>. Como parámetros utilizaremos, el nombre del archivo, el argumento __sep__ para utilizar un tipo de separador u otro y, si no queremos que se muestre el índice del dataframe, utilizaremos el argumento __index__ con valor _none_

# %%
union_outer.to_csv('RESULTADOS.csv', sep=',', index=None)

# %%
union_outer.to_csv('C:/Users/JMMoreno/Downloads/RESULTADOS_dos.csv', sep=',')

# %% [markdown]
# # Ejercicio 8
#
# Se utilizará una base de datos (en .csv) procedente de la web https://openflights.org/data.html , el dataset contiene la siguiente información:
# * **AirportID**: Identificador de cada vuelo para un aeropuerto.
# * **Name**: Nombre del aeropuerto.
# * **City**: Ciudad en la que se encuentra el aeropuerto.
# * **Country**: País o territorio en el que se encuentra el aeropuerto.
# * **IATA**: Código de asociación internacional de transporte aéreo, código del aeorpuerto.
# * **ICAO**: Código de organización civil internacional, código de aeoropuertto.
# * **Latitude**: Coordenada del aeropuerto (latitud).
# * **Longitude**: Coordenada del aeropuerto (longitud).
# * **Altitude**: Altitud del aeropuerto (en pies).
# * **Timezone**: Zona horaria.
# * **DST**: Código referente al continente (Daylight savings time). Europe (E), A (US/CANADA), S (South America), O (Australia), Z (New Zeeland), N (None), U (Unknown).
# * **Tz**: Zona horaria del aeropuerto. Por ejemplo: (America/Los_Angeles).
# * **Type**: Tipo de aeropuerto: airport, station, port, unknown.
# * **Source**: Fuente de datos.
#
# Con la información del dataset realizar lo siguiente:
# * 1 Carga del dataset como dataframe.
# * 2 Muestra las primeras 10 filas del dataframe.
# * 3 Obtén un resumen estadístico.
# * 4 Para este análisis no vamos a emplear las columnas 'AirportID', 'Latitude', 'Longitude' y 'Altitude', elimínalas del dataframe.
# * 5 Vuelve a obtener un resumen estadístico, ¿de qué forma han cambiado los datos?.
# * 6 Sobre el resumen estadístico anterior parece que en la columna TZ hay un valor raro \N, revisa la proporción de los mismos con value_counts.
# * 7 Vuelve a cargar el dataset de modo que se interpreten correctamente los valores nulos (repite el apartado 4, borra las columnas).
# * 8 Revisa los valores nulos de todo el dataframe.
# * 9 Sobrescribe los valores nulos de las columnas IATA e ICAO por el valor 'DESCONOCIDO'
# * 10 Cambia el tipo de las variables DST y TZ como categórico.
# * 11 Obtén un resumen estadístico de las variables categóricas.
# * 12 Agrupa el dataframe por el tipo de aeropuerto, mostrando el conteo de los tipos.
# * 13 Selecciona el nombre de las ciudades cuyo tipo de aeropuerto sea "port"
# * 14 Muestra todas las filas de los campos nombre del aeropuerto, nombre del país y, nombre de la ciudad, cuyo país sea Spain.
# * 15 Muestra el nombre del país y del aeropuerto que sean pertenecientes de la ciudad de Madrid y Barcelona. ¿Todos los registros son de España?
# * 16 Guarda los resultados anteriores en un csv llamado Madrid_Barcelona.csv

# %%
# EN CLASE
