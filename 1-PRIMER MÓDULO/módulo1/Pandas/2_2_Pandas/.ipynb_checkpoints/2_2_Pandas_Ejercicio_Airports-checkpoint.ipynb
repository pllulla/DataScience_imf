# %% [markdown]
# # Ejercicio - Airports
#
# Se utilizará una base de datos (en .csv) procedente de la web https://openflights.org/data.html , el dataset contiene la siguiente información:
# * **AirportID**: Identificador de cada vuelo para un aeropuerto.
# * **Name**: Nombre del aeropuerto.
# * **City**: Ciudad en la que se encuentra el aeropuerto.
# * **Country**: País o territorio en el que se encuentra el aeropuerto.
# * **IATA**: Código de asociación internacional de transporte aéreo, código del aeorpuerto.
# * **ICAO**: Código de organización civil internacional, código de aeoropuertto.
# * **Latitude**: Coordenada del aeropuerto (latitud).
# * **Longitude**: Coordenada del aeropuerto (longitud).
# * **Altitude**: Altitud del aeropuerto (en pies).
# * **Timezone**: Zona horaria.
# * **DST**: Código referente al continente (Daylight savings time). Europe (E), A (US/CANADA), S (South America), O (Australia), Z (New Zeeland), N (None), U (Unknown).
# * **Tz**: Zona horaria del aeropuerto. Por ejemplo: (America/Los_Angeles).
# * **Type**: Tipo de aeropuerto: airport, station, port, unknown.
# * **Source**: Fuente de datos.
#
# Con la información del dataset realizar lo siguiente:
# * 1 Carga del dataset como dataframe.
# * 2 Muestra las primeras 10 filas del dataframe.
# * 3 Obtén un resumen estadístico.
# * 4 Para este análisis no vamos a emplear las columnas 'AirportID', 'Latitude', 'Longitude' y 'Altitude', elimínalas del dataframe.
# * 5 Vuelve a obtener un resumen estadístico, ¿de qué forma han cambiado los datos?.
# * 6 Sobre el resumen estadístico anterior parece que en la columna TZ hay un valor raro \N, revisa la proporción de los mismos con value_counts.
# * 7 Vuelve a cargar el dataset de modo que se interpreten correctamente los valores nulos (repite el apartado 4, borra las columnas).
# * 8 Revisa los valores nulos de todo el dataframe.
# * 9 Sobrescribe los valores nulos de las columnas IATA e ICAO por el valor 'DESCONOCIDO'
# * 10 Cambia el tipo de las variables DST y TZ como categórico.
# * 11 Obtén un resumen estadístico de las variables categóricas.
# * 12 Agrupa el dataframe por el tipo de aeropuerto, mostrando el conteo de los tipos.
# * 13 Selecciona el nombre de las ciudades cuyo tipo de aeropuerto sea "port"
# * 14 Muestra todas las filas de los campos nombre del aeropuerto, nombre del país y, nombre de la ciudad, cuyo país sea Spain.
# * 15 Muestra el nombre del país y del aeropuerto que sean pertenecientes de la ciudad de Madrid y Barcelona. ¿Todos los registros son de España?
# * 16 Guarda los resultados anteriores en un csv llamado Madrid_Barcelona.csv

# %% [markdown]
# # EN CLASE
#
# * 1 Carga del dataset como dataframe.

# %%
import pandas as pd

# %%
df = pd.read_csv("airports.csv", sep=";")

df
# Out:
#        AirportID                                         Name          City  \
# 0              1                               Goroka Airport        Goroka
# 1              2                               Madang Airport        Madang
# 2              3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3              4                               Nadzab Airport        Nadzab
# 4              5  Port Moresby Jacksons International Airport  Port Moresby
# ...          ...                                          ...           ...
# 12663      14107                        Ulan-Ude East Airport      Ulan Ude
# 12664      14108                         Krechevitsy Air Base      Novgorod
# 12665      14109                  Desierto de Atacama Airport       Copiapo
# 12666      14110                           Melitopol Air Base     Melitopol
# 12667      14111                    Lincoln Train Station LNK       Lincoln
#
#                 Country IATA  ICAO                Latitude  \
# 0      Papua New Guinea  GKA  AYGA  -6.081.689.834.590.000
# 1      Papua New Guinea  MAG  AYMD        -520.707.988.739
# 2      Papua New Guinea  HGU  AYMH  -5.826.789.855.957.030
# 3      Papua New Guinea  LAE  AYNZ              -6.569.803
# 4      Papua New Guinea  POM  AYPY  -9.443.380.355.834.960
# ...                 ...  ...   ...                     ...
# 12663            Russia   \N  XIUW  51.849.998.474.121.000
# 12664            Russia   \N  ULLK                  58.625
# 12665             Chile  CPO  SCAT        -272.611.999.512
# 12666           Ukraine   \N  UKDM              46.880.001
# 12667     United States   \N    \N              40.815.833
#
#                     Longitude  Altitude Timezone DST                    TZ  \
# 0             145.391.998.291      5282       10   U  Pacific/Port_Moresby
# 1             145.789.001.465        20       10   U  Pacific/Port_Moresby
# 2      14.429.600.524.902.300      5388       10   U  Pacific/Port_Moresby
# 3                 146.725.977       239       10   U  Pacific/Port_Moresby
# 4      14.722.000.122.070.300       146       10   U  Pacific/Port_Moresby
# ...                       ...       ...      ...  ..                   ...
# 12663  10.773.799.896.240.200      1670       \N  \N                    \N
# 12664  31.385.000.228.881.800        85       \N  \N                    \N
# 12665        -707.791.976.929       670       \N  \N                    \N
# 12666                  35.305         0       \N  \N                    \N
# 12667             -96.713.889      1176       -5   A                    \N
#
#           Type       source
# 0      airport  OurAirports
# 1      airport  OurAirports
# 2      airport  OurAirports
# 3      airport  OurAirports
# 4      airport  OurAirports
# ...        ...          ...
# 12663  airport  OurAirports
# 12664  airport  OurAirports
# 12665  airport  OurAirports
# 12666  airport  OurAirports
# 12667       \N           \N
#
# [12668 rows x 14 columns]

# %% [markdown]
# * 2 Muestra las primeras 10 filas del dataframe.

# %%
df.head(10)
# Out:
#    AirportID                                         Name          City  \
# 0          1                               Goroka Airport        Goroka
# 1          2                               Madang Airport        Madang
# 2          3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3          4                               Nadzab Airport        Nadzab
# 4          5  Port Moresby Jacksons International Airport  Port Moresby
# 5          6                  Wewak International Airport         Wewak
# 6          7                           Narsarsuaq Airport  Narssarssuaq
# 7          8                      Godthaab / Nuuk Airport      Godthaab
# 8          9                        Kangerlussuaq Airport   Sondrestrom
# 9         10                               Thule Air Base         Thule
#
#             Country IATA  ICAO                Latitude  \
# 0  Papua New Guinea  GKA  AYGA  -6.081.689.834.590.000
# 1  Papua New Guinea  MAG  AYMD        -520.707.988.739
# 2  Papua New Guinea  HGU  AYMH  -5.826.789.855.957.030
# 3  Papua New Guinea  LAE  AYNZ              -6.569.803
# 4  Papua New Guinea  POM  AYPY  -9.443.380.355.834.960
# 5  Papua New Guinea  WWK  AYWK        -358.383.011.818
# 6         Greenland  UAK  BGBW         611.604.995.728
# 7         Greenland  GOH  BGGH           6.419.090.271
# 8         Greenland  SFJ  BGSF         670.122.218.992
# 9         Greenland  THU  BGTL         765.311.965.942
#
#                 Longitude  Altitude Timezone DST                    TZ  \
# 0         145.391.998.291      5282       10   U  Pacific/Port_Moresby
# 1         145.789.001.465        20       10   U  Pacific/Port_Moresby
# 2  14.429.600.524.902.300      5388       10   U  Pacific/Port_Moresby
# 3             146.725.977       239       10   U  Pacific/Port_Moresby
# 4  14.722.000.122.070.300       146       10   U  Pacific/Port_Moresby
# 5         143.669.006.348        19       10   U  Pacific/Port_Moresby
# 6        -454.259.986.877       112       -3   E       America/Godthab
# 7        -516.781.005.859       283       -3   E       America/Godthab
# 8        -507.116.031.647       165       -3   E       America/Godthab
# 9        -687.032.012.939       251       -4   E         America/Thule
#
#       Type       source
# 0  airport  OurAirports
# 1  airport  OurAirports
# 2  airport  OurAirports
# 3  airport  OurAirports
# 4  airport  OurAirports
# 5  airport  OurAirports
# 6  airport  OurAirports
# 7  airport  OurAirports
# 8  airport  OurAirports
# 9  airport  OurAirports

# %%
df[:10]
# Out:
#    AirportID                                         Name          City  \
# 0          1                               Goroka Airport        Goroka
# 1          2                               Madang Airport        Madang
# 2          3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3          4                               Nadzab Airport        Nadzab
# 4          5  Port Moresby Jacksons International Airport  Port Moresby
# 5          6                  Wewak International Airport         Wewak
# 6          7                           Narsarsuaq Airport  Narssarssuaq
# 7          8                      Godthaab / Nuuk Airport      Godthaab
# 8          9                        Kangerlussuaq Airport   Sondrestrom
# 9         10                               Thule Air Base         Thule
#
#             Country IATA  ICAO                Latitude  \
# 0  Papua New Guinea  GKA  AYGA  -6.081.689.834.590.000
# 1  Papua New Guinea  MAG  AYMD        -520.707.988.739
# 2  Papua New Guinea  HGU  AYMH  -5.826.789.855.957.030
# 3  Papua New Guinea  LAE  AYNZ              -6.569.803
# 4  Papua New Guinea  POM  AYPY  -9.443.380.355.834.960
# 5  Papua New Guinea  WWK  AYWK        -358.383.011.818
# 6         Greenland  UAK  BGBW         611.604.995.728
# 7         Greenland  GOH  BGGH           6.419.090.271
# 8         Greenland  SFJ  BGSF         670.122.218.992
# 9         Greenland  THU  BGTL         765.311.965.942
#
#                 Longitude  Altitude Timezone DST                    TZ  \
# 0         145.391.998.291      5282       10   U  Pacific/Port_Moresby
# 1         145.789.001.465        20       10   U  Pacific/Port_Moresby
# 2  14.429.600.524.902.300      5388       10   U  Pacific/Port_Moresby
# 3             146.725.977       239       10   U  Pacific/Port_Moresby
# 4  14.722.000.122.070.300       146       10   U  Pacific/Port_Moresby
# 5         143.669.006.348        19       10   U  Pacific/Port_Moresby
# 6        -454.259.986.877       112       -3   E       America/Godthab
# 7        -516.781.005.859       283       -3   E       America/Godthab
# 8        -507.116.031.647       165       -3   E       America/Godthab
# 9        -687.032.012.939       251       -4   E         America/Thule
#
#       Type       source
# 0  airport  OurAirports
# 1  airport  OurAirports
# 2  airport  OurAirports
# 3  airport  OurAirports
# 4  airport  OurAirports
# 5  airport  OurAirports
# 6  airport  OurAirports
# 7  airport  OurAirports
# 8  airport  OurAirports
# 9  airport  OurAirports

# %%
df.iloc[:10]
# Out:
#    AirportID                                         Name          City  \
# 0          1                               Goroka Airport        Goroka
# 1          2                               Madang Airport        Madang
# 2          3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3          4                               Nadzab Airport        Nadzab
# 4          5  Port Moresby Jacksons International Airport  Port Moresby
# 5          6                  Wewak International Airport         Wewak
# 6          7                           Narsarsuaq Airport  Narssarssuaq
# 7          8                      Godthaab / Nuuk Airport      Godthaab
# 8          9                        Kangerlussuaq Airport   Sondrestrom
# 9         10                               Thule Air Base         Thule
#
#             Country IATA  ICAO                Latitude  \
# 0  Papua New Guinea  GKA  AYGA  -6.081.689.834.590.000
# 1  Papua New Guinea  MAG  AYMD        -520.707.988.739
# 2  Papua New Guinea  HGU  AYMH  -5.826.789.855.957.030
# 3  Papua New Guinea  LAE  AYNZ              -6.569.803
# 4  Papua New Guinea  POM  AYPY  -9.443.380.355.834.960
# 5  Papua New Guinea  WWK  AYWK        -358.383.011.818
# 6         Greenland  UAK  BGBW         611.604.995.728
# 7         Greenland  GOH  BGGH           6.419.090.271
# 8         Greenland  SFJ  BGSF         670.122.218.992
# 9         Greenland  THU  BGTL         765.311.965.942
#
#                 Longitude  Altitude Timezone DST                    TZ  \
# 0         145.391.998.291      5282       10   U  Pacific/Port_Moresby
# 1         145.789.001.465        20       10   U  Pacific/Port_Moresby
# 2  14.429.600.524.902.300      5388       10   U  Pacific/Port_Moresby
# 3             146.725.977       239       10   U  Pacific/Port_Moresby
# 4  14.722.000.122.070.300       146       10   U  Pacific/Port_Moresby
# 5         143.669.006.348        19       10   U  Pacific/Port_Moresby
# 6        -454.259.986.877       112       -3   E       America/Godthab
# 7        -516.781.005.859       283       -3   E       America/Godthab
# 8        -507.116.031.647       165       -3   E       America/Godthab
# 9        -687.032.012.939       251       -4   E         America/Thule
#
#       Type       source
# 0  airport  OurAirports
# 1  airport  OurAirports
# 2  airport  OurAirports
# 3  airport  OurAirports
# 4  airport  OurAirports
# 5  airport  OurAirports
# 6  airport  OurAirports
# 7  airport  OurAirports
# 8  airport  OurAirports
# 9  airport  OurAirports

# %% [markdown]
# * 3 Obtén un resumen estadístico.

# %%
len(df.columns)
# Out:
# 14

# %%
df.describe()
# Out:
#           AirportID      Altitude
# count  12668.000000  12668.000000
# mean    7311.584465    831.871093
# std     4202.520098   1498.239733
# min        1.000000  -1266.000000
# 25%     3349.750000     38.000000
# 50%     7771.500000    232.500000
# 75%    10943.250000    883.500000
# max    14111.000000  14472.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12668 entries, 0 to 12667
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   AirportID  12668 non-null  int64
#  1   Name       12668 non-null  object
#  2   City       12619 non-null  object
#  3   Country    12668 non-null  object
#  4   IATA       12668 non-null  object
#  5   ICAO       12667 non-null  object
#  6   Latitude   12668 non-null  object
#  7   Longitude  12668 non-null  object
#  8   Altitude   12668 non-null  int64
#  9   Timezone   12668 non-null  object
#  10  DST        12668 non-null  object
#  11  TZ         12668 non-null  object
#  12  Type       12668 non-null  object
#  13  source     12668 non-null  object
# dtypes: int64(2), object(12)
# memory usage: 1.4+ MB

# %% [markdown]
# * 4 Para este análisis no vamos a emplear las columnas 'AirportID', 'Latitude', 'Longitude' y 'Altitude', elimínalas del dataframe.

# %%
df.columns
# Out:
# Index(['AirportID', 'Name', 'City', 'Country', 'IATA', 'ICAO', 'Latitude',
#        'Longitude', 'Altitude', 'Timezone', 'DST', 'TZ', 'Type', 'source'],
#       dtype='object')

# %%
to_delete = ['AirportID', 'Latitude', 'Longitude', 'Altitude']

# new_columns = df.drop(to_delete, axis=1, inplace=False)

df.drop(to_delete, axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Name', 'City', 'Country', 'IATA', 'ICAO', 'Timezone', 'DST', 'TZ',
#        'Type', 'source'],
#       dtype='object')

# %% [markdown]
# * 5 Vuelve a obtener un resumen estadístico, ¿de qué forma han cambiado los datos?.

# %%
df.describe()
# Out:
#              Name      City        Country   IATA   ICAO Timezone    DST  \
# count       12668     12619          12668  12668  12667    12668  12668
# unique      12330      9673            241   6925   8161       42      8
# top     North Sea  New York  United States     \N     \N        1      E
# freq           21        50           2708   5744   4507     2706   3478
#
#            TZ     Type       source
# count   12668    12668        12668
# unique    312        5            4
# top        \N  airport  OurAirports
# freq     4282     8264         7698

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12668 entries, 0 to 12667
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      12668 non-null  object
#  1   City      12619 non-null  object
#  2   Country   12668 non-null  object
#  3   IATA      12668 non-null  object
#  4   ICAO      12667 non-null  object
#  5   Timezone  12668 non-null  object
#  6   DST       12668 non-null  object
#  7   TZ        12668 non-null  object
#  8   Type      12668 non-null  object
#  9   source    12668 non-null  object
# dtypes: object(10)
# memory usage: 989.8+ KB

# %% [markdown]
# * 6 Sobre el resumen estadístico anterior parece que en la columna TZ hay un valor raro \N, revisa la proporción de los mismos con value_counts.

# %%
df.TZ.value_counts()
# Out:
# \N                    4282
# America/New_York       705
# America/Chicago        402
# Europe/Berlin          323
# America/Anchorage      265
#                       ...
# Europe/Kaliningrad       1
# Africa/Bujumbura         1
# Africa/Banjul            1
# Indian/Mayotte           1
# Europe/Andorra           1
# Name: TZ, Length: 312, dtype: int64

# %%
df["TZ"].value_counts()
# Out:
# \N                    4282
# America/New_York       705
# America/Chicago        402
# Europe/Berlin          323
# America/Anchorage      265
#                       ...
# Europe/Kaliningrad       1
# Africa/Bujumbura         1
# Africa/Banjul            1
# Indian/Mayotte           1
# Europe/Andorra           1
# Name: TZ, Length: 312, dtype: int64

# %%
round(df["TZ"].value_counts() / len(df) * 100, 2)
# Out:
# \N                    33.80
# America/New_York       5.57
# America/Chicago        3.17
# Europe/Berlin          2.55
# America/Anchorage      2.09
#                       ...
# Europe/Kaliningrad     0.01
# Africa/Bujumbura       0.01
# Africa/Banjul          0.01
# Indian/Mayotte         0.01
# Europe/Andorra         0.01
# Name: TZ, Length: 312, dtype: float64

# %%
df.isna().sum()
# Out:
# Name         0
# City        49
# Country      0
# IATA         0
# ICAO         1
# Timezone     0
# DST          0
# TZ           0
# Type         0
# source       0
# dtype: int64

# %% [markdown]
# * 7 Vuelve a cargar el dataset de modo que se interpreten correctamente los valores nulos (repite el apartado 4, borra las columnas).

# %%
df = pd.read_csv("airports.csv", sep=";", na_values=["\\N"])

# %%
to_delete = ['AirportID', 'Latitude', 'Longitude', 'Altitude']

# new_columns = df.drop(to_delete, axis=1, inplace=False)

df.drop(to_delete, axis=1, inplace=True)

# %%
df.TZ.value_counts()
# Out:
# America/New_York      705
# America/Chicago       402
# Europe/Berlin         323
# America/Anchorage     265
# Europe/Paris          241
#                      ...
# Europe/Kaliningrad      1
# Africa/Bujumbura        1
# Africa/Banjul           1
# Indian/Mayotte          1
# Europe/Andorra          1
# Name: TZ, Length: 311, dtype: int64

# %% [markdown]
# * 8 Revisa los valores nulos de todo el dataframe.

# %%
df.isna().sum()
# Out:
# Name           0
# City          49
# Country        0
# IATA        5744
# ICAO        4508
# Timezone     353
# DST          353
# TZ          4282
# Type        1651
# source      1651
# dtype: int64

# %%
df.isna().sum() / len(df) * 100
# Out:
# Name         0.000000
# City         0.386801
# Country      0.000000
# IATA        45.342596
# ICAO        35.585728
# Timezone     2.786549
# DST          2.786549
# TZ          33.801705
# Type        13.032839
# source      13.032839
# dtype: float64

# %% [markdown]
# * 9 Sobrescribe los valores nulos de las columnas IATA e ICAO por el valor 'DESCONOCIDO'

# %%
df.IATA.fillna("DESCONOCIDO", inplace=True)
df.ICAO.fillna("DESCONOCIDO", inplace=True)

# %%
df.isna().sum()
# Out:
# Name           0
# City          49
# Country        0
# IATA           0
# ICAO           0
# Timezone     353
# DST          353
# TZ          4282
# Type        1651
# source      1651
# dtype: int64

# %%
df.IATA.value_counts()
# Out:
# DESCONOCIDO    5744
# GKA               1
# DGE               1
# CES               1
# GUL               1
#                ...
# JGA               1
# JLR               1
# IDR               1
# GOI               1
# CPO               1
# Name: IATA, Length: 6925, dtype: int64

# %% [markdown]
# * 10 Cambia el tipo de las variables DST y TZ como categórico.

# %%
df["DST"] = pd.Categorical(df["DST"])
df["TZ"]  = pd.Categorical(df["TZ"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12668 entries, 0 to 12667
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      12668 non-null  object
#  1   City      12619 non-null  object
#  2   Country   12668 non-null  object
#  3   IATA      12668 non-null  object
#  4   ICAO      12668 non-null  object
#  5   Timezone  12315 non-null  float64
#  6   DST       12315 non-null  category
#  7   TZ        8386 non-null   category
#  8   Type      11017 non-null  object
#  9   source    11017 non-null  object
# dtypes: category(2), float64(1), object(7)
# memory usage: 839.9+ KB

# %% [markdown]
# * 11 Obtén un resumen estadístico de las variables categóricas.

# %%
df.describe(include="category")
# Out:
#           DST                TZ
# count   12315              8386
# unique      7               311
# top         E  America/New_York
# freq     3478               705

# %%
df.describe(exclude="float")
# Out:
#              Name      City        Country         IATA         ICAO    DST  \
# count       12668     12619          12668        12668        12668  12315
# unique      12330      9673            241         6925         8161      7
# top     North Sea  New York  United States  DESCONOCIDO  DESCONOCIDO      E
# freq           21        50           2708         5744         4508   3478
#
#                       TZ     Type       source
# count               8386    11017        11017
# unique               311        4            3
# top     America/New_York  airport  OurAirports
# freq                 705     8264         7698

# %% [markdown]
# * 12 Agrupa el dataframe por el tipo de aeropuerto, mostrando el conteo de los tipos.

# %%
df.columns
# Out:
# Index(['Name', 'City', 'Country', 'IATA', 'ICAO', 'Timezone', 'DST', 'TZ',
#        'Type', 'source'],
#       dtype='object')

# %%
df.groupby(["Type"]).count()
# Out:
#          Name  City  Country  IATA  ICAO  Timezone   DST    TZ  source
# Type
# airport  8264  8215     8264  8264  8264      7911  7911  7148    8264
# port      101   101      101   101   101       101   101    66     101
# station  1332  1332     1332  1332  1332      1332  1332   414    1332
# unknown  1320  1320     1320  1320  1320      1320  1320   758    1320

# %%
df.Type.value_counts()
# Out:
# airport    8264
# station    1332
# unknown    1320
# port        101
# Name: Type, dtype: int64

# %% [markdown]
# * 13 Selecciona el nombre de las ciudades cuyo tipo de aeropuerto sea "port"

# %%
df.Type == "port"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12663    False
# 12664    False
# 12665    False
# 12666    False
# 12667    False
# Name: Type, Length: 12668, dtype: bool

# %%
df[(df.Type == "port")][["Name", "Type"]]
# Out:
#                                           Name  Type
# 6074                          Macau Ferry Pier  port
# 6438                     Stockholm Cruise Port  port
# 6439                   Helsingborg Cruise Port  port
# 6444                      Helsinki Cruise Port  port
# 6565                          Sakaiminato Port  port
# ...                                        ...   ...
# 9948                  Ludington Ferry Terminal  port
# 9949                  Manitowoc Ferry Terminal  port
# 10184                    Fuyong Ferry Terminal  port
# 10207  Osaka Port International Ferry Terminal  port
# 10208       Hakata Port International Terminal  port
#
# [101 rows x 2 columns]

# %% [markdown]
# * 14 Muestra todas las filas de los campos nombre del aeropuerto, nombre del país y, nombre de la ciudad, cuyo país sea Spain.

# %%
df[(df.Country == "Spain")][["Name", "Country", "City"]]
# Out:
#                                          Name Country                    City
# 1030                    Fuerteventura Airport   Spain           Fuerteventura
# 1031                           Hierro Airport   Spain                  Hierro
# 1032                         La Palma Airport   Spain  Santa Cruz De La Palma
# 1033                     Gran Canaria Airport   Spain            Gran Canaria
# 1034                        Lanzarote Airport   Spain                Arrecife
# ...                                       ...     ...                     ...
# 11437                     Madrid Estacion Sur   Spain                  Madrid
# 11438                     Granada Bus Station   Spain                 Granada
# 11879       Palma de Mallorca Cruise Terminal   Spain       Palma de Mallorca
# 12234                      Algeciras Heliport   Spain               Algeciras
# 12386  Región de Murcia International Airport   Spain                  Murcia
#
# [145 rows x 3 columns]

# %% [markdown]
# * 15 Muestra el nombre del país y del aeropuerto que sean pertenecientes de la ciudad de Madrid y Barcelona. ¿Todos los registros son de España?

# %%
results = df[(df.City == "Madrid") | (df.City == "Barcelona")][["Country", 
                                                      "Name", 
                                                      "City"]]

results
# Out:
#          Country                                               Name       City
# 1188       Spain                    Barcelona International Airport  Barcelona
# 1194       Spain                                    Getafe Air Base     Madrid
# 1198       Spain               Adolfo Suárez Madrid–Barajas Airport     Madrid
# 1214       Spain                                   Torrejón Airport     Madrid
# 1217       Spain                                     Cuatro Vientos     Madrid
# 2690   Venezuela  General José Antonio Anzoategui International ...  Barcelona
# 6302       Spain                          Barcelona Cruise Terminal  Barcelona
# 8046       Spain                                             Atocha     Madrid
# 8053       Spain                                  Chamartin Station     Madrid
# 8055       Spain                                           Aeroport  Barcelona
# 8056       Spain                                  Passeig de Gracia  Barcelona
# 8057       Spain                                              Sants  Barcelona
# 8846       Spain                                    Barajas Station     Madrid
# 9156       Spain                         Aeropuerto T4 Madrid Metro     Madrid
# 10033      Spain                                  Estacio de Franca  Barcelona
# 10264      Spain                            Placa d Espanya Station  Barcelona
# 10435      Spain                             Cuatro Vientos Airport     Madrid
# 11435      Spain                                    Barcelona-Sants  Barcelona
# 11437      Spain                                Madrid Estacion Sur     Madrid

# %% [markdown]
# * 16 Guarda los resultados anteriores en un csv llamado Madrid_Barcelona.csv

# %%
results.to_csv("Madrid_Barcelona.csv", sep=";")

# %%
a = pd.read_csv("Madrid_Barcelona.csv", sep=";")

a
# Out:
#     Unnamed: 0    Country                                               Name  \
# 0         1188      Spain                    Barcelona International Airport
# 1         1194      Spain                                    Getafe Air Base
# 2         1198      Spain               Adolfo Suárez Madrid–Barajas Airport
# 3         1214      Spain                                   Torrejón Airport
# 4         1217      Spain                                     Cuatro Vientos
# 5         2690  Venezuela  General José Antonio Anzoategui International ...
# 6         6302      Spain                          Barcelona Cruise Terminal
# 7         8046      Spain                                             Atocha
# 8         8053      Spain                                  Chamartin Station
# 9         8055      Spain                                           Aeroport
# 10        8056      Spain                                  Passeig de Gracia
# 11        8057      Spain                                              Sants
# 12        8846      Spain                                    Barajas Station
# 13        9156      Spain                         Aeropuerto T4 Madrid Metro
# 14       10033      Spain                                  Estacio de Franca
# 15       10264      Spain                            Placa d Espanya Station
# 16       10435      Spain                             Cuatro Vientos Airport
# 17       11435      Spain                                    Barcelona-Sants
# 18       11437      Spain                                Madrid Estacion Sur
#
#          City
# 0   Barcelona
# 1      Madrid
# 2      Madrid
# 3      Madrid
# 4      Madrid
# 5   Barcelona
# 6   Barcelona
# 7      Madrid
# 8      Madrid
# 9   Barcelona
# 10  Barcelona
# 11  Barcelona
# 12     Madrid
# 13     Madrid
# 14  Barcelona
# 15  Barcelona
# 16     Madrid
# 17  Barcelona
# 18     Madrid
